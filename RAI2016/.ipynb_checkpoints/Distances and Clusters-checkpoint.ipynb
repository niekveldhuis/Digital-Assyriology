# %% [markdown]
# # Distance Measurements: Sumerian Literature
#
# This is a work-in-progress Notebook.

# %%
import pandas as pd
import glob
import re
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# First read the directory with the cleaned ETCSL texts. These files contain lemmatization in ORACC (ePSD2 style). The texts list lemmatizations per line.

# %%
path =r'../Scrape-etcsl/cleaned/' # use your path
allFiles = glob.glob(path + "/*.txt")
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
etcsl_data = pd.concat(list_)
etcsl_data.head()
# Out:
#   etcsl_no                         text_name version l_no  \
# 0  c.0.1.1  Ur III catalogue from Nibru (N1)     NaN    1
# 1  c.0.1.1  Ur III catalogue from Nibru (N1)     NaN    2
# 2  c.0.1.1  Ur III catalogue from Nibru (N1)     NaN    3
# 3  c.0.1.1  Ur III catalogue from Nibru (N1)     NaN    4
# 4  c.0.1.1  Ur III catalogue from Nibru (N1)     NaN    5
#
#                                                 text
# 0                                sux:dubsaŋ[first]AJ
# 1  sux:Enki[1]DN sux:unu[dwelling]N sux:gal[big]V...
# 2                                sux:anzag[horizon]N
# 3  sux:anŋi[eclipse]N sux:zu[know]V/t sux:ama[mot...
# 4                 sux:gi[thicket]N sux:tuku[rock]V/t

# %% [markdown]
# In order to transform this DataFrame into a proper Document Term Matrix we need to discard the columns `version` and `l_no` and concatenate all the text that belongs to a single composition. Some line have no content in the `text` column - these lines need to be dropped.
#
# First select the relevant columns and drop the rows that have no text content.

# %%
etcsl_data = etcsl_data[['etcsl_no', 'text_name', 'text']]
etcsl_data = etcsl_data.dropna()
etcsl_data.head()
# Out:
#   etcsl_no                         text_name  \
# 0  c.0.1.1  Ur III catalogue from Nibru (N1)
# 1  c.0.1.1  Ur III catalogue from Nibru (N1)
# 2  c.0.1.1  Ur III catalogue from Nibru (N1)
# 3  c.0.1.1  Ur III catalogue from Nibru (N1)
# 4  c.0.1.1  Ur III catalogue from Nibru (N1)
#
#                                                 text
# 0                                sux:dubsaŋ[first]AJ
# 1  sux:Enki[1]DN sux:unu[dwelling]N sux:gal[big]V...
# 2                                sux:anzag[horizon]N
# 3  sux:anŋi[eclipse]N sux:zu[know]V/t sux:ama[mot...
# 4                 sux:gi[thicket]N sux:tuku[rock]V/t

# %% [markdown]
# Group the rows by `etcsl_no` and apply the `join` function to the `text` column. Transform the aggregated data into a new DataFrame.

# %%
etcsl_bytext = etcsl_data['text'].groupby(etcsl_data['etcsl_no']).apply(' '.join)
etcsl_bytext_df = pd.DataFrame(etcsl_bytext)
etcsl_bytext_df.head()
# Out:
#                                                        text
# etcsl_no
# c.0.1.1   sux:dubsaŋ[first]AJ sux:Enki[1]DN sux:unu[dwel...
# c.0.1.2   sux:diŋir[deity]N sux:šembizida[kohl]N sux:dar...
# c.0.2.01  sux:lugal[king]N sux:šag[heart]N sux:lugal[kin...
# c.0.2.02  sux:Enlil[1]DN sux:sud[distant]V/i sux:nam[lor...
# c.0.2.03  sux:lugal[king]N sux:mu[name]N sux:niŋul[everl...

# %% [markdown]
# Create a DataFrame of `etcsl_no` and `text_name` equivalencies, with `etcsl_no` set as index (row names). Then merge this DataFrame with the the `etctsl_bytext_df` using the indexes.

# %%
etcsl_numbers_names = etcsl_data[['etcsl_no', 'text_name']].drop_duplicates().set_index('etcsl_no')
etcsl_data_df = pd.merge(etcsl_numbers_names, etcsl_bytext_df, right_index=True, left_index=True)
etcsl_data_df.head()
# Out:
#                                  text_name  \
# etcsl_no
# c.0.1.1   Ur III catalogue from Nibru (N1)
# c.0.1.2      Ur III catalogue at Yale (Y1)
# c.0.2.01      OB catalogue from Nibru (N2)
# c.0.2.02    OB catalogue in the Louvre (L)
# c.0.2.03       OB catalogue from Urim (U1)
#
#                                                        text
# etcsl_no
# c.0.1.1   sux:dubsaŋ[first]AJ sux:Enki[1]DN sux:unu[dwel...
# c.0.1.2   sux:diŋir[deity]N sux:šembizida[kohl]N sux:dar...
# c.0.2.01  sux:lugal[king]N sux:šag[heart]N sux:lugal[kin...
# c.0.2.02  sux:Enlil[1]DN sux:sud[distant]V/i sux:nam[lor...
# c.0.2.03  sux:lugal[king]N sux:mu[name]N sux:niŋul[everl...

# %% [markdown]
# Transfrom the DataFrame into a Document Term Matrix (DTM) by using `CountVecorizer`. This function uses a Regular Expression (`token_pattern`) to indicate how to find the beginning and end of each word (or token). In lemmatized Sumerian, a space indicates the boundary between two lemmas. The expression `r.[^ ]+` means: any combination of characters, except the space.
#
# The output of the CountVectorizer (`etcsl_dtm`) is not in a human-readable format. It is transformed into another DataFrame, with the ETCSL numbers as index.
#
# The length of each composition in ETCSL may be computed by adding up all the numbers in a row. The text length will be used at various places in further computations.

# %%
cv = CountVectorizer(analyzer='word', token_pattern=r'[^ ]+')
etcsl_dtm = cv.fit_transform(etcsl_data_df['text'])
etcsl_dtm_df = pd.DataFrame(etcsl_dtm.toarray(), columns = cv.get_feature_names(), index = etcsl_data_df.index.values)
etcsl_text_length =  etcsl_dtm_df.sum(axis=1)
etcsl_dtm_df.head()
# Out:
#           sux-x-emesal:am-mu-uc[3]nu  sux-x-emesal:aŋ[do]v/t  \
# c.0.1.1                            0                       0
# c.0.1.2                            0                       0
# c.0.2.01                           0                       0
# c.0.2.02                           0                       0
# c.0.2.03                           0                       0
#
#           sux-x-emesal:aŋ[sky]n  sux-x-emesal:aŋ[thing]n  \
# c.0.1.1                       0                        0
# c.0.1.2                       0                        0
# c.0.2.01                      0                        0
# c.0.2.02                      0                        0
# c.0.2.03                      0                        0
#
#           sux-x-emesal:aŋba[gift]n  sux-x-emesal:aŋdara[rag]n  \
# c.0.1.1                          0                          0
# c.0.1.2                          0                          0
# c.0.2.01                         0                          0
# c.0.2.02                         0                          0
# c.0.2.03                         0                          0
#
#           sux-x-emesal:aŋgig[bad-thing]n  sux-x-emesal:aŋhulu[evil]n  \
# c.0.1.1                                0                           0
# c.0.1.2                                0                           0
# c.0.2.01                               0                           0
# c.0.2.02                               0                           0
# c.0.2.03                               0                           0
#
#           sux-x-emesal:aŋlam[garment]n  sux-x-emesal:aŋsub[polishing]n  \
# c.0.1.1                              0                               0
# c.0.1.2                              0                               0
# c.0.2.01                             0                               0
# c.0.2.02                             0                               0
# c.0.2.03                             0                               0
#
#                  ...          sux:šusuen[1]rn  sux:šutubur[mixture]n  \
# c.0.1.1          ...                        0                      0
# c.0.1.2          ...                        0                      0
# c.0.2.01         ...                        0                      0
# c.0.2.02         ...                        1                      0
# c.0.2.03         ...                        0                      0
#
#           sux:šutug[reed-hut]n  sux:šutum[storehouse]n  sux:šutur[garment]n  \
# c.0.1.1                      0                       0                    0
# c.0.1.2                      0                       0                    0
# c.0.2.01                     0                       0                    0
# c.0.2.02                     0                       0                    0
# c.0.2.03                     0                       0                    0
#
#           sux:šuziana[1]dn  sux:šuš[cover]v/t  sux:šuʾi[barber]n  \
# c.0.1.1                  0                  0                  0
# c.0.1.2                  0                  0                  0
# c.0.2.01                 0                  0                  0
# c.0.2.02                 0                  0                  0
# c.0.2.03                 0                  0                  0
#
#           sux:šuʾu[stone]n  sux:šuʾura[goose]n
# c.0.1.1                  0                   0
# c.0.1.2                  0                   0
# c.0.2.01                 0                   0
# c.0.2.02                 0                   0
# c.0.2.03                 0                   0
#
# [5 rows x 4304 columns]

# %%
words_l = list(etcsl_dtm_df.columns.values)

# %%
words_l_error = [word for word in words_l if '-' in word]
words_l_error
# Out:
# ['sux-x-emesal:am-mu-uc[3]nu',
#  'sux-x-emesal:aŋ[do]v/t',
#  'sux-x-emesal:aŋ[sky]n',
#  'sux-x-emesal:aŋ[thing]n',
#  'sux-x-emesal:aŋba[gift]n',
#  'sux-x-emesal:aŋdara[rag]n',
#  'sux-x-emesal:aŋgig[bad-thing]n',
#  'sux-x-emesal:aŋhulu[evil]n',
#  'sux-x-emesal:aŋlam[garment]n',
#  'sux-x-emesal:aŋsub[polishing]n',
#  'sux-x-emesal:ašer[lament]n',
#  'sux-x-emesal:ašte[chair]n',
#  'sux-x-emesal:damal[wide]v/i',
#  'sux-x-emesal:di[go]v/i',
#  'sux-x-emesal:di[one]nu',
#  'sux-x-emesal:dimmer[deity]n',
#  'sux-x-emesal:dumu[child]n',
#  'sux-x-emesal:dumuzid[1]dn',
#  'sux-x-emesal:dumuzidabzuk[1]dn',
#  'sux-x-emesal:duʾuš[bird]n',
#  'sux-x-emesal:elum[bison]n',
#  'sux-x-emesal:eneŋ[word]n',
#  'sux-x-emesal:enki[1]dn',
#  'sux-x-emesal:enlil[1]dn',
#  'sux-x-emesal:ere[slave]n',
#  'sux-x-emesal:ereškigalak[1]dn',
#  'sux-x-emesal:eridug[1]sn',
#  'sux-x-emesal:eze[sheep]n',
#  'sux-x-emesal:ga[bring]v/t',
#  'sux-x-emesal:gašan[lady]n',
#  'sux-x-emesal:gelleŋ[forsake]v/i',
#  'sux-x-emesal:gi[thicket]n',
#  'sux-x-emesal:gin[female-worker]n',
#  'sux-x-emesal:hemal[plenty]n',
#  'sux-x-emesal:ibi[eye]n',
#  'sux-x-emesal:immal[cow]n',
#  'sux-x-emesal:inanak[1]dn',
#  'sux-x-emesal:ir[bring]v/t',
#  'sux-x-emesal:irikug[1]sn',
#  'sux-x-emesal:iziŋ[festival]n',
#  'sux-x-emesal:kanaŋ[land]n',
#  'sux-x-emesal:kig[place]n',
#  'sux-x-emesal:kiŋinana[1]mn',
#  'sux-x-emesal:kumal[inspector]n',
#  'sux-x-emesal:libirsi[friend]n',
#  'sux-x-emesal:lugalbanda[1]dn',
#  'sux-x-emesal:ma[house]n',
#  'sux-x-emesal:mal[be]v/i',
#  'sux-x-emesal:mar[place]v/t',
#  'sux-x-emesal:marza[rites]n',
#  'sux-x-emesal:maš.gurum[plant]n',
#  'sux-x-emesal:me[i]ip',
#  'sux-x-emesal:mer[dagger]n',
#  'sux-x-emesal:meri[foot]n',
#  'sux-x-emesal:merisi[toe]n',
#  'sux-x-emesal:mudna[spouse]n',
#  'sux-x-emesal:mudru[scepter]n',
#  'sux-x-emesal:mugib[priestess]n',
#  'sux-x-emesal:mula[policeman]n',
#  'sux-x-emesal:mulu[person]n',
#  'sux-x-emesal:mulug[needle]n',
#  'sux-x-emesal:mungar[farmer]n',
#  'sux-x-emesal:mungur[property]n',
#  'sux-x-emesal:munkud[tax-collector]n',
#  'sux-x-emesal:munu[cowherd]n',
#  'sux-x-emesal:mutin[falcon]n',
#  'sux-x-emesal:mutin[male]n',
#  'sux-x-emesal:mutin[woman]n',
#  'sux-x-emesal:muš[penis]n',
#  'sux-x-emesal:muš[tree]n',
#  'sux-x-emesal:mušbar[fire?]n',
#  'sux-x-emesal:mušlabi[silence]n',
#  'sux-x-emesal:mušnimmar[palm]n',
#  'sux-x-emesal:mušnud[bed]n',
#  'sux-x-emesal:muštin[vine]n',
#  'sux-x-emesal:muštug[ear]n',
#  'sux-x-emesal:muššub[lot]n',
#  'sux-x-emesal:nama[potash]n',
#  'sux-x-emesal:naŋ[fate]n',
#  'sux-x-emesal:naŋegir[ladyship]n',
#  'sux-x-emesal:naŋerim[oath]n',
#  'sux-x-emesal:naŋgašan[ladyship]n',
#  'sux-x-emesal:naŋgin[~worker]n',
#  'sux-x-emesal:naŋkugzu[wisdom]n',
#  'sux-x-emesal:naŋlulu[humanity]n',
#  'sux-x-emesal:naŋsag[pleasure]n',
#  'sux-x-emesal:naŋsipad[shepherdship]n',
#  'sux-x-emesal:naŋtar[fate]n',
#  'sux-x-emesal:naŋtil[life]n',
#  'sux-x-emesal:naŋumun[priesthood]n',
#  'sux-x-emesal:nindara[1]dn',
#  'sux-x-emesal:ninegalak[1]dn',
#  'sux-x-emesal:ningal[1]dn',
#  'sux-x-emesal:ningikuga[1]dn',
#  'sux-x-emesal:ninhursaŋak[1]dn',
#  'sux-x-emesal:ninirigalak[1]dn',
#  'sux-x-emesal:ninisinak[1]dn',
#  'sux-x-emesal:ninmah[1]dn',
#  'sux-x-emesal:ninmarkik[1]dn',
#  'sux-x-emesal:ninsumunak[1]dn',
#  'sux-x-emesal:ninurtak[1]dn',
#  'sux-x-emesal:ninŋišzidak[1]dn',
#  'sux-x-emesal:ninšubur[1]dn',
#  'sux-x-emesal:niŋinmar[building]n',
#  'sux-x-emesal:nunus[woman]n',
#  'sux-x-emesal:padanunus[1]tn',
#  'sux-x-emesal:peš₃[fig]n',
#  'sux-x-emesal:subad[shepherd]n',
#  'sux-x-emesal:sudmal[long-lasting]n',
#  'sux-x-emesal:ta[what?]qp',
#  'sux-x-emesal:tagin[how?]qp',
#  'sux-x-emesal:taš[why?]qp',
#  'sux-x-emesal:tugmezera[mourning-garment]n',
#  'sux-x-emesal:u[oil]n',
#  'sux-x-emesal:umun[lord]n',
#  'sux-x-emesal:umunsik[ruler]n',
#  'sux-x-emesal:uru[city]n',
#  'sux-x-emesal:urubad[~city]n',
#  'sux-x-emesal:ze[warp]v/t',
#  'sux-x-emesal:zeb[good]v/i',
#  'sux-x-emesal:zeŋ[give]v/t',
#  'sux-x-emesal:ŋatumdug[1]dn',
#  'sux-x-emesal:ŋen[be]v/i',
#  'sux-x-emesal:ŋen[tiara]n',
#  'sux-x-emesal:ŋen[willow]n',
#  'sux-x-emesal:ŋeštin[1]dn',
#  'sux-x-emesal:ŋeštinanak[1]dn',
#  'sux-x-emesal:ša[advice]n',
#  'sux-x-emesal:šab[heart]n',
#  'sux-x-emesal:šagabata[yesterday?]n',
#  'sux-x-emesal:šamar[starvation]n',
#  'sux-x-emesal:še[cvne]n',
#  'sux-x-emesal:šeb[brick]n',
#  'sux-x-emesal:šegkuršagak[1]tn',
#  'sux-x-emesal:šenbuna[turtle]n',
#  'sux-x-emesal:šenkilim[mongoose]n',
#  'sux-x-emesal:šenkilim[rodent]n',
#  'sux-x-emesal:šer[trust]n',
#  'sux-x-emesal:šerŋal[authoritative]aj',
#  'sux-x-emesal:ši[life]n',
#  'sux-x-emesal:šipaŋ[breath]n',
#  'sux-x-emesal:šumdum[lip]n',
#  'sux-x-emesal:šumun[grass]n',
#  'sux-x-emesal:šušer[emblem]n',
#  'sux:1-kam-ma[1st]nu',
#  'sux:10-kam-ma[10th]nu',
#  'sux:11-kam-ma[11th]nu-',
#  'sux:12-kam-ma[12th]nu',
#  'sux:15-kam-ma[15th]nu',
#  'sux:2-kam-ma[2nd]nu',
#  'sux:3-kam-ma[3rd]nu',
#  'sux:4-kam-ma[4th]nu',
#  'sux:5-kam-ma[5th]nu',
#  'sux:6-kam-ma[6th]nu',
#  'sux:7-kam-ma[7th]nu',
#  'sux:8-kam-ma[8th]nu',
#  'sux:9-kam-ma[9th]nu',
#  'sux:a[bird-cry]n',
#  'sux:adlu[disabled-person]n',
#  'sux:al-dug[desire]v/t',
#  'sux:ambar[reed-bed]n',
#  'sux:anbar[mid-day]n',
#  'sux:anbarkar[mid-day]n',
#  'sux:azbal[neck-stock]n',
#  'sux:azgu[neck-stock]n',
#  'sux:balare[other-side]n',
#  'sux:birun[threshing-floor?]n',
#  'sux:bu.ud.bar[impure-male]n',
#  'sux:bur₂-bur₂-babbar[type-of-noise]n',
#  'sux:dilibipila[bird-cry]n',
#  'sux:du-bu-ul-da-ba-al[liquid-noise]n',
#  'sux:dub-dab₅[rumbling-noise]n',
#  'sux:dub[go-around]v/t',
#  'sux:dub[pole-pin]n',
#  'sux:dugŋal[well-disposed?]aj',
#  'sux:dum-dam[rumbling-noise]n',
#  'sux:dumusaŋ[first-born]n',
#  'sux:dun-dun[dun-dun]v',
#  'sux:ebir[vessel-stand]n',
#  'sux:edubbaʾa[scribal-school]n',
#  'sux:ekurun[liquor-room]n',
#  'sux:enbiše[how-long]qp',
#  'sux:enkud[tax-collector]n',
#  'sux:ennameše[how-long?]qp',
#  'sux:ennamešeam[as-far-as]cnj',
#  'sux:entukumše[as-long-as]ma',
#  'sux:enše[how-long]qp',
#  'sux:erib[in-law]n',
#  'sux:eŋešpu[wrestling-house]n',
#  'sux:eʾuburak[animal-pen]n',
#  'sux:gagkula[fish-hook]n',
#  'sux:gakkul[mash-tub]n',
#  'sux:gana[come-on!]j',
#  'sux:gaʾil[milk-carrier]n',
#  'sux:giriʾilu[bird-cry]n',
#  'sux:gu-mer[thrive]v/t',
#  'sux:gum₂-ga-am₃[animal-noise]n',
#  'sux:gure[that-side]n',
#  'sux:guʾe[this-side]o',
#  'sux:guʾen[throne-room]n',
#  'sux:gu₂-un-gu₂-un[animal-noise]n',
#  'sux:ha.ha.ha[mix-up?]v/t',
#  'sux:heʾam[so-be-it]n',
#  'sux:hu-un-ha[animal-noise]n',
#  'sux:idlurugu[ordeal-river]n',
#  'sux:igen[but-no]ma',
#  'sux:igi.x[boat-part]n',
#  'sux:iginzu[as-if]ma',
#  'sux:im.bu.bu[hod-carrier]n',
#  'sux:iziŋiʾedena[atmospheric-phenomenon]n',
#  'sux:izzida[side-wall]n',
#  'sux:kab[nose-rope]n',
#  'sux:ki-aŋ[love]v/t',
#  'sux:kibala[rebel-land]n',
#  'sux:kišibla[seal-bearer]n',
#  'sux:kišibŋal[seal-bearer]n',
#  'sux:kiʾerim[enemy-territory]n',
#  'sux:kiʾumun[place-of-learning]n',
#  'sux:ku-du[ku-du]v',
#  'sux:kun-ka₃-an[liquid-noise]n',
#  'sux:kurbad[mountain-top]n',
#  'sux:lugize[reed-cutter]n',
#  'sux:luharmušenak[bird-trapper]n',
#  'sux:lukinnatum[nest-hunter]n',
#  'sux:lumud[bolt-handler]n',
#  'sux:lušahšum[pig-butcher]n',
#  'sux:masar[fish-storage]n',
#  'sux:ma₂.gin₂[boat-builder]n',
#  'sux:mete[appropriate-thing]n',
#  'sux:meše[where-to?]qp',
#  'sux:mi-ne[mi-ne]n',
#  'sux:mugu[water-lift]n',
#  'sux:mul-ma-al[type-of-noise]n',
#  'sux:mur-ma-ra[animal-noise]n',
#  'sux:murmara-ša[roar]v/t',
#  'sux:murum[in-law]n',
#  'sux:mussa[in-law]n',
#  'sux:mussatur[in-law]n',
#  'sux:mušendu[bird-catcher]n',
#  'sux:muš₃.ka.u.gud[cup-bearer]n',
#  'sux:muʾimma[last-year]n',
#  'sux:nadiššu[hammer-stone?]n',
#  'sux:nam-x[nam-x]n',
#  'sux:nam.ad.kid[basket-weaving]n',
#  'sux:namdubsar[the-scribal-arts]n',
#  'sux:namdumuzi[child-delivering?]n',
#  'sux:namemesig[false-speech]n',
#  'sux:namennuŋ[safe-keeping]n',
#  'sux:namensik[office-of-ruler]n',
#  'sux:namerin[field-working]n',
#  'sux:namguzala[~throne-bearer]n',
#  'sux:namkuŋal[irrigation-control]n',
#  'sux:namsumun[old-age]n',
#  'sux:namušbar[in-law-status]n',
#  'sux:nangama[be-that-as-it-may]ma',
#  'sux:nim-ŋir[flash]v/t',
#  'sux:ninda[seed-funnel]n',
#  'sux:niŋal[awe-inspiring]aj',
#  'sux:niŋdu[appropriate-thing]n',
#  'sux:niŋgig[bad-thing]n',
#  'sux:niŋtab[fire-box]n',
#  'sux:niŋziŋal[living-creature]n',
#  'sux:pu-ud-pa-ad[rumbling-noise]n',
#  'sux:ri-ri[ri-ri]v',
#  'sux:sahar.hub₂[dust-heap]n',
#  'sux:sahargi[dust-guard]n',
#  'sux:sakeškešsa[bug-ridden]n',
#  'sux:sala[bug-ridden]aj',
#  'sux:saŋ.du[smitten-person]n',
#  'sux:si-sa[straighten]v/t',
#  'sux:sikipa[head-hair]n',
#  'sux:sudŋal[long-lasting]n',
#  'sux:sugzag-gu[destroy]v/t',
#  'sux:suh₃-sah₄[rumbling-noise]n',
#  'sux:sulum-mar[slander]v/t',
#  'sux:tikutikumae[bird-cry]n',
#  'sux:tirida[bird-cry]n',
#  'sux:tuditum[toggle-pin]n',
#  'sux:tugmudura[mourning-garment]n',
#  'sux:tum[cross-beam]n',
#  'sux:u-dug[admire]v/t',
#  'sux:ududu[reed-bundle]n',
#  'sux:ugu-de[disappear]v/t',
#  'sux:uludig[bird-cry]n',
#  'sux:umma[old-woman]n',
#  'sux:usar-ak[sharpen]v/t',
#  'sux:ušbar[in-law]n',
#  'sux:ušub[brick-mold]n',
#  'sux:zadim[stone-cutter]n',
#  'sux:zagmuk[new-year]n',
#  'sux:ze[gall-bladder]n',
#  'sux:zi-ig-za-ag[rumbling-noise]n',
#  'sux:zib[donkey-bridle]n',
#  'sux:zirigum[irrigation-device]n',
#  'sux:ziŋal[living-things]n',
#  'sux:zur[take-care-of]v/t',
#  'sux:ŋala-dag[cease]v/t',
#  'sux:ŋeštug-ulu[forget]v/t',
#  'sux:ŋešusala[boat-part]n',
#  'sux:šagia[cup-bearer]n',
#  'sux:ša₆.tur[~date-palm]n',
#  'sux:še-ša[moan]v/i',
#  'sux:šeg-gi[make-noise]v/t',
#  'sux:šegaradin[grain-stack]n',
#  'sux:šitan[water-channel]n',
#  'sux:šu-dag[roam-around]v/t',
#  'sux:šu-du[complete]v/t',
#  'sux:šu-huz[burn]v/t',
#  'sux:šu-teŋ[accept]v/t',
#  'sux:šu-tubul[mix]v/t',
#  'sux:šu-šanšaša[search]v/t',
#  'sux:šukin-dab[prostrate]v/t',
#  'sux:šutug[reed-hut]n']
