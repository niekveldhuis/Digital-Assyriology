# %% [markdown]
# # Overlap in Lexical and Literary Vocabulary
#
# Comparing the vocabulary of Old Babylonian lexical texts (from Nippur) and the vocabulary of the Sumerian literary corpus as represented in [ETCSL](http://etcsl.orinst.ox.ac.uk/).

# %%
import pandas as pd
import os
from sklearn.feature_extraction.text import CountVectorizer
from matplotlib import pyplot as plt
from matplotlib_venn import venn2

# %% [markdown]
# # Read ETCSL Data Files
# Read the directory with the clean ETCSL files (in `.csv` format). The variable `files` is a list that holds all file names. Iterate through the list, but skip if the file name does not end in `.txt`. Create a dataframe for each text and add those dataframes to a list named `list_`. Concatenate all the dataframes in the list to form a single dataframe.
#
# Each row is a line of text from [ETCSL](http://etcsl.orinst.ox.ac.uk/) in lemmatized format, according to [ePSD2](http://build-oracc.museum.upenn.edu/epsd2) standards.
#
# Drop rows that have no lemmatized words.
#
# Lowercase all lemmatizations (column `text`).

# %%
files = os.listdir('../Scrape-etcsl/Cleaned/')
files.sort()
list_ = []
for entry in files:
    if entry[-4:] == ".txt" and entry[0] == "c":
        file = '../Scrape-etcsl/Cleaned/' + entry
        df = pd.read_csv(file)
        list_.append(df)
etcsl = pd.concat(list_).dropna(subset=["text"])
etcsl["text"] = etcsl["text"].str.lower()
etcsl
# Out:
#     etcsl_no                         text_name     version l_no  \
# 0    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    1
# 1    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    2
# 2    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    3
# 3    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    4
# 4    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    5
# 5    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    6
# 6    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    7
# 7    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    8
# 8    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN    9
# 9    c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   10
# 10   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   11
# 11   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   12
# 12   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   13
# 13   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   14
# 14   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   15
# 15   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   16
# 16   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   17
# 17   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   18
# 18   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   19
# 19   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   20
# 20   c.0.1.1  Ur III catalogue from Nibru (N1)         NaN   21
# 0    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    1
# 1    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    2
# 2    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    3
# 3    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    4
# 4    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    5
# 5    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    6
# 6    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    7
# 7    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    8
# 8    c.0.1.2     Ur III catalogue at Yale (Y1)         NaN    9
# ..       ...                               ...         ...  ...
# 176  c.6.2.5   Proverbs: of unknown provenance    YBC 7320    1
# 177  c.6.2.5   Proverbs: of unknown provenance    YBC 7320    2
# 178  c.6.2.5   Proverbs: of unknown provenance    YBC 7331    1
# 179  c.6.2.5   Proverbs: of unknown provenance    YBC 7331    2
# 180  c.6.2.5   Proverbs: of unknown provenance    YBC 7344    1
# 181  c.6.2.5   Proverbs: of unknown provenance    YBC 7344    2
# 182  c.6.2.5   Proverbs: of unknown provenance    YBC 7347    1
# 183  c.6.2.5   Proverbs: of unknown provenance    YBC 7347    2
# 184  c.6.2.5   Proverbs: of unknown provenance    YBC 7348    1
# 185  c.6.2.5   Proverbs: of unknown provenance    YBC 7348    2
# 186  c.6.2.5   Proverbs: of unknown provenance    YBC 7693    1
# 187  c.6.2.5   Proverbs: of unknown provenance    YBC 7693    2
# 188  c.6.2.5   Proverbs: of unknown provenance    YBC 9908    1
# 189  c.6.2.5   Proverbs: of unknown provenance    YBC 9908    2
# 190  c.6.2.5   Proverbs: of unknown provenance    YBC 9916    1
# 191  c.6.2.5   Proverbs: of unknown provenance    YBC 9916    2
# 192  c.6.2.5   Proverbs: of unknown provenance    Homsy 21    1
# 193  c.6.2.5   Proverbs: of unknown provenance    Homsy 22    1
# 194  c.6.2.5   Proverbs: of unknown provenance    NBC 8072    1
# 195  c.6.2.5   Proverbs: of unknown provenance       P 376    1
# 196  c.6.2.5   Proverbs: of unknown provenance  TIM 10/1 2    1
# 197  c.6.2.5   Proverbs: of unknown provenance   UIOM 1999    1
# 198  c.6.2.5   Proverbs: of unknown provenance    YBC 1993    1
# 199  c.6.2.5   Proverbs: of unknown provenance    YBC 7282    1
# 200  c.6.2.5   Proverbs: of unknown provenance    YBC 7297    1
# 201  c.6.2.5   Proverbs: of unknown provenance    YBC 7300    1
# 202  c.6.2.5   Proverbs: of unknown provenance    YBC 8934    1
# 203  c.6.2.5   Proverbs: of unknown provenance    YBC 8937    1
# 204  c.6.2.5   Proverbs: of unknown provenance    YBC 9906    1
# 205  c.6.2.5   Proverbs: of unknown provenance    YBC 9912    1
#
#                                                   text
# 0                                  sux:dubsaŋ[first]aj
# 1    sux:enki[1]dn sux:unu[dwelling]n sux:gal[big]v...
# 2                                  sux:anzag[horizon]n
# 3    sux:anŋi[eclipse]n sux:zu[know]v/t sux:ama[mot...
# 4                   sux:gi[thicket]n sux:tuku[rock]v/t
# 5                                      sux:me[battle]n
# 6    sux:mašmaš[sorcerer]n sux:erim[enemy]n sux:kur...
# 7    sux:ŋiriŋena[path]n sux:enki[1]dn sux:ki[place...
# 8                  sux:šag[heart]n sux:1-kam-ma[1st]nu
# 9                                  sux:dubsaŋ[first]aj
# 10           sux:kaskal[way]n sux:7[7]nu sux:me[be]v/i
# 11                                      sux:lilia[1]dn
# 12          sux:igi[eye]n sux:7[7]nu sux:kur[enter]v/i
# 13       sux:šul[youth]v/i sux:a[arm]n sux:la[hang]v/t
# 14       sux:gu[cord]n sux:sig[put]v/t sux:gal[big]v/i
# 15                  sux:ŋiriŋena[path]n sux:lilia[1]dn
# 16                 sux:šag[heart]n sux:1-kam-ma[1st]nu
# 17   sux:ŋiri[foot]n sux:lu[person]n sux:inim[word]...
# 18   sux:ŋiriŋena[path]n sux:lu[person]n sux:pad[fi...
# 19                                 sux:ŋiriŋena[path]n
# 20   sux:iribala[city]n sux:aš[curse]n sux:dug[spea...
# 0    sux:diŋir[deity]n sux:šembizida[kohl]n sux:dar...
# 1    sux:enlil[1]dn sux:dug[speak]v/t sux:kur[diffe...
# 2    sux:lugal[king]n sux:an[sky]n sux:kug[pure]v/i...
# 3    sux:lugal[king]n sux:enlil[1]dn sux:gub[stand]v/i
# 4      sux:en[lord]n sux:gud[ox]n sux:banda[junior]v/i
# 5    sux:šerzid[radiance]n sux:en[lord]n sux:gal[bi...
# 6    sux:munus[woman]n sux:zid[right]v/i sux:mi[cvn...
# 7                   sux:en[lord]n sux:sulim[radiance]n
# 8    sux:ursaŋ[hero]n sux:en[lord]n sux:huš[reddish...
# ..                                                 ...
# 176  sux:lala[plenty]n sux:niŋ[thing]n sux:e[house]...
# 177  sux:namtur[smallness]n sux:dam[spouse]n sux:tu...
# 178  sux:inim[word]n sux:niŋsisa[justice]n sux:de[b...
# 179  sux:idlurugu[1]dn sux:šag[heart]n sux:u[admira...
# 180     sux:lulu[man]n sux:diŋir[deity]n sux:me[be]v/i
# 181  sux:nu[not]v/i sux:gal[big]v/i sux:nu[not]v/i ...
# 182  sux:lu[person]n sux:igištu[foremost]aj sux:izi...
# 183  sux:lu[person]n sux:egir[back]n sux:dug[speak]...
# 184  sux:amaš[sheepfold]n sux:šeŋbar[animal]n sux:e...
# 185  sux:ildum[band]n sux:50[50]nu sux:u[grass]n su...
# 186                      sux:ŋešgu[stock]n sux:ku[ku]v
# 187  sux:engar[farmer]n sux:gud[ox]n sux:addir[hire...
# 188  sux:niŋgur[property]n sux:niŋgur[property]n su...
# 189  sux:kur[enter]v/i sux:si-sa[straighten]v/t sux...
# 190  sux:lu[person]n sux:aŋala[sack]n sux:kešed[bin...
# 191                  sux:šag[heart]n sux:dab[seize]v/t
# 192  sux:mu[name]n sux:še[call]v/t sux:ur[dog]n sux...
# 193  sux:nin[lady]n sux:amar[young]n sux:an[sky]n s...
# 194  sux:luma[1]dn sux:lu[person]n sux:niŋ[thing]n ...
# 195   sux:banšur[table]n sux:enlil[1]dn sux:ŋal[be]v/i
# 196  sux:aba[who?]qp sux:zi[life]n sux:tuku[acquire...
# 197  sux:iri[city]n sux:adlu[disabled-person]n sux:...
# 198  sux:na[stone]n sux:kalag[strong]v/i sux:kizurr...
# 199  sux:aya[father]n sux:hili[attractiveness]n sux...
# 200  sux:ku.ga₂.nun.tir.ra[bird]n sux:gu[voice]n su...
# 201  sux:tur.uz.za[duck?]n sux:gu[voice]n sux:de[po...
# 202  sux:šum[give]v/t sux:lu[person]n sux:us[follow...
# 203  sux:lugal[king]n sux:dubsar[scribe]n sux:lugal...
# 204  sux:lu[person]n sux:si[horn]n sux:sa[equal]v/t...
# 205  sux:haš[thigh]n sux:gid[long]v/i sux:lu[person...
#
# [34954 rows x 5 columns]

# %% [markdown]
# # Read Lexical Data
#
# Essentially following the same process as in the preceding cell.

# %%
files = os.listdir("Lex-Data")
files.sort()
list_ = []
for entry in files:
    if entry[-4:] == ".txt":
        df = pd.read_csv("Lex-Data/" + entry)
        list_.append(df)
lexical = pd.concat(list_).dropna(subset=["text"])
lexical["text"] = lexical["text"].str.lower()
lexical
# Out:
#            id_text         text_name  l_no  \
# 0    dcclt/Q000001  OB Nippur Ura 03     1
# 1    dcclt/Q000001  OB Nippur Ura 03     2
# 2    dcclt/Q000001  OB Nippur Ura 03     3
# 3    dcclt/Q000001  OB Nippur Ura 03     4
# 4    dcclt/Q000001  OB Nippur Ura 03     5
# 5    dcclt/Q000001  OB Nippur Ura 03     6
# 6    dcclt/Q000001  OB Nippur Ura 03     7
# 7    dcclt/Q000001  OB Nippur Ura 03     8
# 8    dcclt/Q000001  OB Nippur Ura 03     9
# 9    dcclt/Q000001  OB Nippur Ura 03    10
# 10   dcclt/Q000001  OB Nippur Ura 03    11
# 11   dcclt/Q000001  OB Nippur Ura 03    12
# 12   dcclt/Q000001  OB Nippur Ura 03    13
# 13   dcclt/Q000001  OB Nippur Ura 03    14
# 14   dcclt/Q000001  OB Nippur Ura 03    15
# 15   dcclt/Q000001  OB Nippur Ura 03    16
# 16   dcclt/Q000001  OB Nippur Ura 03    17
# 17   dcclt/Q000001  OB Nippur Ura 03    18
# 18   dcclt/Q000001  OB Nippur Ura 03    19
# 19   dcclt/Q000001  OB Nippur Ura 03    20
# 20   dcclt/Q000001  OB Nippur Ura 03    21
# 21   dcclt/Q000001  OB Nippur Ura 03    22
# 22   dcclt/Q000001  OB Nippur Ura 03    23
# 23   dcclt/Q000001  OB Nippur Ura 03    24
# 24   dcclt/Q000001  OB Nippur Ura 03    25
# 25   dcclt/Q000001  OB Nippur Ura 03    26
# 26   dcclt/Q000001  OB Nippur Ura 03    27
# 27   dcclt/Q000001  OB Nippur Ura 03    28
# 28   dcclt/Q000001  OB Nippur Ura 03    29
# 29   dcclt/Q000001  OB Nippur Ura 03    30
# ..             ...               ...   ...
# 188  dcclt/Q002268   OB Nippur Ugumu  223'
# 189  dcclt/Q002268   OB Nippur Ugumu  224'
# 190  dcclt/Q002268   OB Nippur Ugumu  225'
# 191  dcclt/Q002268   OB Nippur Ugumu  226'
# 192  dcclt/Q002268   OB Nippur Ugumu  227'
# 193  dcclt/Q002268   OB Nippur Ugumu  228'
# 194  dcclt/Q002268   OB Nippur Ugumu  229'
# 195  dcclt/Q002268   OB Nippur Ugumu  230'
# 196  dcclt/Q002268   OB Nippur Ugumu  231'
# 197  dcclt/Q002268   OB Nippur Ugumu  241'
# 198  dcclt/Q002268   OB Nippur Ugumu  242'
# 199  dcclt/Q002268   OB Nippur Ugumu  243'
# 200  dcclt/Q002268   OB Nippur Ugumu  244'
# 201  dcclt/Q002268   OB Nippur Ugumu  246'
# 202  dcclt/Q002268   OB Nippur Ugumu  260'
# 203  dcclt/Q002268   OB Nippur Ugumu  261'
# 204  dcclt/Q002268   OB Nippur Ugumu  262'
# 205  dcclt/Q002268   OB Nippur Ugumu  263'
# 206  dcclt/Q002268   OB Nippur Ugumu  264'
# 207  dcclt/Q002268   OB Nippur Ugumu  265'
# 208  dcclt/Q002268   OB Nippur Ugumu  266'
# 209  dcclt/Q002268   OB Nippur Ugumu  267'
# 210  dcclt/Q002268   OB Nippur Ugumu  268'
# 211  dcclt/Q002268   OB Nippur Ugumu  269'
# 212  dcclt/Q002268   OB Nippur Ugumu  282'
# 213  dcclt/Q002268   OB Nippur Ugumu  283'
# 214  dcclt/Q002268   OB Nippur Ugumu  284'
# 215  dcclt/Q002268   OB Nippur Ugumu  285'
# 216  dcclt/Q002268   OB Nippur Ugumu  286'
# 217  dcclt/Q002268   OB Nippur Ugumu  287'
#
#                                                   text
# 0                sux:udu[sheep]n sux:niga[fattened]v/i
# 1    sux:udu[sheep]n sux:niga[fattened]v/i sux:sag[...
# 2    sux:udu[sheep]n sux:niga[fattened]v/i sux:ŋirg...
# 3                      sux:udu[sheep]n sux:nita[male]n
# 4    sux:udu[sheep]n sux:nita[male]n sux:ŋešdu[bree...
# 5                        sux:udu[sheep]n sux:u[grass]n
# 6                     sux:udu[sheep]n sux:utuwa[stud]n
# 7                    sux:udu[sheep]n sux:aslum[sheep]n
# 8    sux:udu[sheep]n sux:aslum[sheep]n sux:niga[fat...
# 9    sux:udu[sheep]n sux:aslum[sheep]n sux:niga[fat...
# 10   sux:udu[sheep]n sux:aslum[sheep]n sux:gukkal[s...
# 11                  sux:udu[sheep]n sux:gukkal[sheep]n
# 12   sux:udu[sheep]n sux:gukkal[sheep]n sux:niga[fa...
# 13   sux:udu[sheep]n sux:gukkal[sheep]n sux:niga[fa...
# 14   sux:udu[sheep]n sux:gukkal[sheep]n sux:ib[hips...
# 15                      sux:udu[sheep]n sux:tu[sheep]n
# 16                 sux:udu[sheep]n sux:ad[crippled]v/i
# 17             sux:udu[sheep]n sux:kudkudra[disabled]n
# 18                 sux:udu[sheep]n sux:deg[collect]v/t
# 19   sux:udu[sheep]n sux:na[cvne]n sux:deg[collect]v/t
# 20                  sux:udu[sheep]n sux:kur[mountain]n
# 21                 sux:udu[sheep]n sux:hi.gina[unmng]n
# 22    sux:udu[sheep]n sux:diŋir[deity]n sux:gu[eat]v/t
# 23     sux:udu[sheep]n sux:urmah[lion]n sux:gu[eat]v/t
# 24    sux:udu[sheep]n sux:urbara[wolf]n sux:gu[eat]v/t
# 25                  sux:udu[sheep]n sux:šurum[litter]n
# 26     sux:udu[sheep]n sux:gag[pock]n sux:šub[fall]v/t
# 27     sux:udu[sheep]n sux:mur[lung]n sux:šub[fall]v/t
# 28    sux:udu[sheep]n sux:gum[mange]n sux:šub[fall]v/t
# 29      sux:udu[sheep]n sux:ib[hips]n sux:gig[sick]v/i
# ..                                                 ...
# 188                                  sux:akan[nipple]n
# 189                                  sux:ubur[breast]n
# 190                    sux:ubur[breast]n sux:ga[milk]n
# 191                                  sux:masila[heel]n
# 192                   sux:saŋ[head]n sux:masila[heel]n
# 193               sux:murub[middle]n sux:masila[heel]n
# 194                  sux:siki[hair]n sux:masila[heel]n
# 195                               sux:murgu[shoulder]n
# 196                               sux:murgu[shoulder]n
# 197                                      sux:ur[root]n
# 198                                      sux:ur[root]n
# 199                                    sux:haš[thigh]n
# 200                                    sux:haš[thigh]n
# 201                                     sux:saŋ[head]n
# 202                        sux:gu[neck]n sux:pah[leg]n
# 203                        sux:gu[neck]n sux:pah[leg]n
# 204                                    sux:ŋiri[foot]n
# 205                     sux:igi[face]n sux:ŋiri[foot]n
# 206               sux:murgu[shoulder]n sux:ŋiri[foot]n
# 207                  sux:šusi[finger]n sux:ŋiri[foot]n
# 208                 sux:murub[middle]n sux:ŋiri[foot]n
# 209  sux:zukešed[troop]n sux:šusi[finger]n sux:ŋiri...
# 210  sux:umbin[nail]n sux:šusi[finger]n sux:gal[big...
# 211  sux:umbin[nail]n sux:šusi[finger]n sux:ŋiri[fo...
# 212                           sux:namŋuruš[manliness]n
# 213                             sux:namursaŋ[heroism]n
# 214                                  sux:namabba[age]n
# 215                                  sux:ŋissu[shade]n
# 216                                  sux:ŋissu[shade]n
# 217                                 sux:ŋešgen[limbs]n
#
# [8956 rows x 4 columns]

# %% [markdown]
# # First Approximation
# Extract the vocabulary of ETCSL and the lexical texts. Count each word separately. Thus, in the lexical item `gud an-na` we count the words `gud` (ox) and `an` (heaven) separately to see if those words appear in the literary corpus as well. This approach, therefore, does not take account of attestations of `gud an-na` in both corpora.

# %%
etcsl_words = ' '.join(list(etcsl["text"]))
lexical_words = " ".join(list(lexical["text"]))
etcsl_words_s = set(etcsl_words.split())
lexical_words_s = set(lexical_words.split())

# %%
plt.figure(figsize=(8,8))
lit_legend = "literary (" + str(len(etcsl_words_s)) + ')'
lex_legend = "lexical (" + str(len(lexical_words_s)) + ")"
venn2([etcsl_words_s, lexical_words_s], (lit_legend, lex_legend))
plt.show()

# %% [markdown]
# # Mark Multiple Word Expressions
#
# Iterate through the list of lexical vocabulary (beginning with the longest items) and check to see if the item contains multiple lemmatizations (contains spaces). If so, the item is an `expression` and the spaces are replaced by `*`. This will ensure that the expressions are dealt with as single units, for instance `gud an-na` (Bull of Heaven), lemmatized as `gud[bull]n an[heaven]n` becomes the unit `gud[bull]n*an[heaven]n`.
#
# The method `.str.replace()` in `Pandas` uses regular expressions - a setting that cannot be switched off. It is necessary, therefore, to indicate that certain characters are to be read literally and not as regex special characters. This is true, in particular, for the characters `[` and `]` that surround the Guide Word (as in `gud[bull]n`). These characters, therefore, are preceded by the `escape character` `\` in the search/replace function.
#
# The constituent words (lemmatizations) of all expressions are now connected by `*` both in the `etcsl` dataframe and in the `lex_vocab` list.
#
# The resulting Venn diagram shows how many lexical *entries* are attested in the literary corpus. Of course, many (but not all) individual words (such as `gud` and `an`) are indeed entries somewhere in the lexical corpus and are therefore also registered in the overlap section.

# %%
lex_vocab = list(set(lexical["text"]))
lex_vocab = [item.replace(" ", "*") for item in lex_vocab]

# %%
lex_vocab.sort(key=len, reverse=True)
for item in lex_vocab:
    if "*" in item:
        findwhat = item.replace("[", "\[")
        findwhat = findwhat.replace("]", "\]")
        findwhat = findwhat.replace("*", " ")
        etcsl["text"] = etcsl["text"].str.replace(findwhat, item)

# %%
etcsl[etcsl["text"].str.contains("*", regex=False)]
# Out:
#      etcsl_no                                text_name       version l_no  \
# 13    c.0.1.1         Ur III catalogue from Nibru (N1)           NaN   14
# 17    c.0.1.1         Ur III catalogue from Nibru (N1)           NaN   18
# 6     c.0.1.2            Ur III catalogue at Yale (Y1)           NaN    7
# 17    c.0.1.2            Ur III catalogue at Yale (Y1)           NaN   18
# 24    c.0.1.2            Ur III catalogue at Yale (Y1)           NaN   25
# 1    c.0.2.01             OB catalogue from Nibru (N2)           NaN    2
# 9    c.0.2.01             OB catalogue from Nibru (N2)           NaN   10
# 15   c.0.2.01             OB catalogue from Nibru (N2)           NaN   16
# 29   c.0.2.01             OB catalogue from Nibru (N2)           NaN   30
# 40   c.0.2.01             OB catalogue from Nibru (N2)           NaN   41
# 59   c.0.2.01             OB catalogue from Nibru (N2)           NaN   60
# 61   c.0.2.01             OB catalogue from Nibru (N2)           NaN   62
# 5    c.0.2.02           OB catalogue in the Louvre (L)           NaN   10
# 28   c.0.2.02           OB catalogue in the Louvre (L)           NaN   33
# 43   c.0.2.02           OB catalogue in the Louvre (L)           NaN   48
# 48   c.0.2.02           OB catalogue in the Louvre (L)           NaN   53
# 60   c.0.2.02           OB catalogue in the Louvre (L)           NaN   65
# 13   c.0.2.03              OB catalogue from Urim (U1)           NaN   14
# 20   c.0.2.03              OB catalogue from Urim (U1)           NaN   21
# 4    c.0.2.04              OB catalogue from Urim (U2)           NaN    5
# 8    c.0.2.04              OB catalogue from Urim (U2)           NaN    9
# 26   c.0.2.04              OB catalogue from Urim (U2)           NaN   27
# 51   c.0.2.04              OB catalogue from Urim (U2)           NaN   52
# 54   c.0.2.04              OB catalogue from Urim (U2)           NaN   55
# 11   c.0.2.06             OB catalogue from Nibru (N3)           NaN   12
# 30   c.0.2.06             OB catalogue from Nibru (N3)           NaN   31
# 7    c.0.2.11  OB catalogue at Andrews University (B4)           NaN    8
# 1    c.0.2.12                OB catalogue at Yale (Y2)           NaN   A2
# 13   c.0.2.13             OB catalogue from Nibru (N6)           NaN   14
# 21   c.0.2.13             OB catalogue from Nibru (N6)           NaN   22
# ..        ...                                      ...           ...  ...
# 20    c.6.2.5          Proverbs: of unknown provenance      IM 62823  B10
# 22    c.6.2.5          Proverbs: of unknown provenance      IM 62823  B12
# 23    c.6.2.5          Proverbs: of unknown provenance      BM 80722   A1
# 26    c.6.2.5          Proverbs: of unknown provenance      BM 80722   A4
# 32    c.6.2.5          Proverbs: of unknown provenance      BM 80722  A10
# 39    c.6.2.5          Proverbs: of unknown provenance      BM 80722   B4
# 70    c.6.2.5          Proverbs: of unknown provenance  UM 29-16-519   A6
# 87    c.6.2.5          Proverbs: of unknown provenance      IM 43438   A2
# 89    c.6.2.5          Proverbs: of unknown provenance      IM 43438   A4
# 94    c.6.2.5          Proverbs: of unknown provenance      IM 43438   B4
# 111   c.6.2.5          Proverbs: of unknown provenance      YBC 4677    1
# 115   c.6.2.5          Proverbs: of unknown provenance      YBC 4677    5
# 117   c.6.2.5          Proverbs: of unknown provenance      YBC 4677    7
# 134   c.6.2.5          Proverbs: of unknown provenance  UM 29-15-748    6
# 137   c.6.2.5          Proverbs: of unknown provenance      BM 57994   A2
# 158   c.6.2.5          Proverbs: of unknown provenance      YBC 7301    1
# 159   c.6.2.5          Proverbs: of unknown provenance      YBC 7301    2
# 164   c.6.2.5          Proverbs: of unknown provenance      YBC 7351    1
# 167   c.6.2.5          Proverbs: of unknown provenance      YBC 7352    1
# 171   c.6.2.5          Proverbs: of unknown provenance     Emory 106    2
# 173   c.6.2.5          Proverbs: of unknown provenance      NBC 8070    2
# 176   c.6.2.5          Proverbs: of unknown provenance      YBC 7320    1
# 179   c.6.2.5          Proverbs: of unknown provenance      YBC 7331    2
# 182   c.6.2.5          Proverbs: of unknown provenance      YBC 7347    1
# 188   c.6.2.5          Proverbs: of unknown provenance      YBC 9908    1
# 192   c.6.2.5          Proverbs: of unknown provenance      Homsy 21    1
# 200   c.6.2.5          Proverbs: of unknown provenance      YBC 7297    1
# 201   c.6.2.5          Proverbs: of unknown provenance      YBC 7300    1
# 203   c.6.2.5          Proverbs: of unknown provenance      YBC 8937    1
# 204   c.6.2.5          Proverbs: of unknown provenance      YBC 9906    1
#
#                                                   text
# 13       sux:šul[youth]v/i sux:a[arm]n*sux:la[hang]v/t
# 17   sux:ŋiri[foot]n sux:lu[person]n*sux:inim[word]...
# 6    sux:munus[woman]n sux:zid[right]v/i sux:mi[cvn...
# 17   sux:lugal[king]n sux:inim[word]n*sux:sag[good]v/i
# 24   sux:lugal[king]n sux:ŋeštug[ear]n*sux:daŋal[wi...
# 1     sux:lugal[king]n sux:mi[cvne]n*sux:dug[speak]v/t
# 9    sux:en[lord]n sux:kur[mountain]n sux:lu[person...
# 15       sux:kud[fish]n sux:e[house]n*sux:du[build]v/t
# 29   sux:gi[thicket]n sux:ana[what?]qp sux:gu[voice...
# 40   sux:an[sky]n sux:gal[big]v/i sux:ki[place]n*su...
# 59                     sux:lu[person]n*sux:lil[ghost]n
# 61         sux:a[water]n*sux:dug[good]v/i sux:ur[dog]n
# 5    sux:en[lord]n sux:kur[mountain]n sux:lu[person...
# 28   sux:an[sky]n sux:gal[big]v/i sux:ki[place]n*su...
# 43       sux:kud[fish]n sux:e[house]n*sux:du[build]v/t
# 48   sux:gi[thicket]n sux:ana[what?]qp sux:gu[voice...
# 60   sux:ki[place]n*sux:dug[good]v/i sux:ama[mother...
# 13   sux:en[lord]n sux:kur[mountain]n sux:lu[person...
# 20   sux:ud[storm]n sux:ešbar[decision]n*sux:kiŋ[se...
# 4     sux:lugal[king]n sux:mi[cvne]n*sux:dug[speak]v/t
# 8    sux:en[lord]n sux:kur[mountain]n sux:lu[person...
# 26   sux:an[sky]n sux:gal[big]v/i sux:ki[place]n*su...
# 51       sux:kud[fish]n sux:e[house]n*sux:du[build]v/t
# 54    sux:lu[person]n sux:ilu[song]n*sux:dug[speak]v/t
# 11   sux:munus[woman]n sux:zid[right]v/i sux:me[bei...
# 30     sux:subur[slave]n sux:šu[hand]n*sux:mu[grow]v/t
# 7     sux:lugal[king]n sux:mi[cvne]n*sux:dug[speak]v/t
# 1     sux:lugal[king]n sux:mi[cvne]n*sux:dug[speak]v/t
# 13   sux:e[house]n*sux:sikil[pure]v/i sux:ki[place]...
# 21   sux:ab[cow]n sux:nun[prince]n sux:an[sky]n sux...
# ..                                                 ...
# 20   sux:a[water]n*sux:šu[hand]n sux:na[stone]n sux...
# 22   sux:ukuš[cucumber]n sux:ki[place]n*sux:dug[goo...
# 23   sux:ma[ship]n*sux:dilmun[1]gn sux:tumu[wind]n ...
# 26   sux:id[river]n sux:a[water]n*sux:mah[great]v/i...
# 32   sux:hala[share]n sux:ganum[stand]n sux:tur[sma...
# 39     sux:urmah[lion]n sux:gu[voice]n*sux:de[pour]v/t
# 70                     sux:šu[hand]n*sux:ŋar[place]v/t
# 87   sux:nirŋal[authoritative]aj sux:kugzu[wise]aj ...
# 89                   sux:dam[spouse]n*sux:dam[spouse]n
# 94   sux:lu[person]n sux:niŋtuku[rich]aj sux:lu[per...
# 111  sux:šah[pig]n*sux:niga[fattened]v/i sux:šum[sl...
# 115  sux:niŋ[thing]n*sux:tuku[acquire]v/t sux:igi[e...
# 117    sux:šu[hand]n*sux:tutu[cvve]v/t sux:zu[know]v/t
# 134  sux:šah[pig]n sux:niŋ[thing]n*sux:la[hang]v/t ...
# 137  sux:gala[vulva]n sux:tug[textile]n sux:šu[hand...
# 158  sux:gud[ox]n*sux:šugi[senior]n sux:ki[place]n ...
# 159  sux:usu[strength]n sux:niŋ[thing]n*sux:udbita[...
# 164  sux:dikud[judge]n sux:niŋgina[truth]n sux:hulu...
# 167  sux:lu[person]n*sux:inim[word]n sux:gin[firm]v...
# 171  sux:ambar[reed-bed]n sux:eria[wasteland]n sux:...
# 173      sux:alal[tube]n sux:a[water]n*sux:de[pour]v/t
# 176  sux:lala[plenty]n sux:niŋ[thing]n sux:e[house]...
# 179  sux:idlurugu[1]dn sux:šag[heart]n sux:u[admira...
# 182  sux:lu[person]n*sux:igištu[foremost]aj sux:izi...
# 188  sux:niŋgur[property]n sux:niŋgur[property]n*su...
# 192  sux:mu[name]n*sux:še[call]v/t sux:ur[dog]n sux...
# 200  sux:ku.ga₂.nun.tir.ra[bird]n sux:gu[voice]n*su...
# 201  sux:tur.uz.za[duck?]n sux:gu[voice]n*sux:de[po...
# 203  sux:lugal[king]n sux:dubsar[scribe]n*sux:lugal...
# 204  sux:lu[person]n sux:si[horn]n*sux:sa[equal]v/t...
#
# [5788 rows x 5 columns]

# %%
etcsl_words2 = ' '.join(list(etcsl["text"]))
etcsl_words_s2 = set(etcsl_words2.split())
lexical_words_s2 = set(lex_vocab)

# %%
plt.figure(figsize=(8,8))
lit_legend = "literary (" + str(len(etcsl_words_s2)) + ')'
lex_legend = "lexical (" + str(len(lexical_words_s2)) + ")"
venn2([etcsl_words_s2, lexical_words_s2], (lit_legend, lex_legend))
plt.show()

# %% [markdown]
# # Add them Up
# By creating the union of the two sets (the set with individual words and the set with the lexical entries only) we get the most complete comparison of the two corpora. Here `gud[oxen]N*an[heaven]N`, `gud[oxen]N` and `an[heaven]N` are all counted as words, whether or not `gud` and `an` actually appear as such in the lexical corpus.

# %%
etcsl_words_s3 = etcsl_words_s | etcsl_words_s2
lexical_words_s3 = lexical_words_s | lexical_words_s2

# %%
plt.figure(figsize=(8,8))
lit_legend = "literary (" + str(len(etcsl_words_s3)) + ')'
lex_legend = "lexical (" + str(len(lexical_words_s3)) + ")"
venn2([etcsl_words_s3, lexical_words_s3], (lit_legend, lex_legend))
plt.show()

# %%
len(etcsl_words_s), len(etcsl_words_s2), len(etcsl_words_s3)
# Out:
# (4304, 4979, 5003)

# %% [markdown]
# # Create a Corpus
# The etcsl dataframe is organized by line. The `aggregate` function assembles the lines that belong to a single composition. The resulting dataframe has 394 entries, one for each composition.

# %%
corpus = etcsl.groupby([etcsl["etcsl_no"], etcsl["text_name"]]).aggregate({"text": " ".join}).reset_index()

# %% [markdown]
# # Document Term Matrix
# The corpus is transformed into a Document Term Matrix (or DTM) in which each word (or expression) is a column and each row a Sumerian composition. The lexical vocabulary is used as a filter (only words that appear in the lexical texts are allowed in the DTM).
#
# First sort the lexical vocabulary alphabetically.
#
# Use CountVectorizer (from Sklearn) to initiate the DTM. The `token_pattern` indicates what a word looks like and what signals the end of a word. In modern corpora this can be fairly complex (including spaces, commas, full stops, etc.) but in the current corpus a space will always separate one token from the next. The regex `r'[^ ]+'` means "any sequence of characters, except space".
#
# Transform the DTM to a dataframe.
#
# NB a DTM is not necessary for the raw comparison/Venn diagram - only for further inspection.

# %%
cv = CountVectorizer(analyzer='word', token_pattern=r'[^ ]+', binary = False, vocabulary=lex_vocab)
etcsl_dtm = cv.fit_transform(corpus['text'])
#etcsl_df = pd.DataFrame(etcsl_dtm.toarray(), columns= cv.get_feature_names(), index=corpus["etcsl_no"])
etcsl_df = pd.DataFrame(etcsl_dtm.toarray(), columns= lex_vocab, index=corpus["etcsl_no"])

# %%
etcsl_df

# %% [markdown]
# # Words in Lexical Texts not in ETCSL
# If a word or expression in the lexical corpus is never used in the literary texts from [ETCSL](http://etcsl.orinst.ox.ac.uk/) the sum of its column will be `0`.
#
# Give the number of columns (the number of unique words and expressions in the lexical texts), the number of words/expressions never used in the ETCSL corpus and the relation between those two numbers in percent.

# %%
lex_not_in_etcsl = etcsl_df.loc[:, etcsl_df.sum()==0]
len(etcsl_df.columns), len(lex_not_in_etcsl.columns), str(len(lex_not_in_etcsl.columns)/len(etcsl_df.columns)*100) + "%"

# %% [markdown]
# # Simplify
# The above may be an overly complex way of doing it.
# Alternative: make a full dtm of etcsl (without a vocabulary constraint); make the etcsl vocabulary and lexical vocabulary into sets that can be subtracted from each other.

# %%
cv = CountVectorizer(analyzer='word', token_pattern=r'[^ ]+', binary = False)
etcsl2_dtm = cv.fit_transform(corpus['text'])
etcsl2_df = pd.DataFrame(etcsl2_dtm.toarray(), columns= cv.get_feature_names(), index=corpus["etcsl_no"])
etcsl_vocab_s = set(etcsl2_df.columns)
lex_vocab_s = set(lex_vocab)
diff_e_l = list(etcsl_vocab_s - lex_vocab_s)
diff_l_e = list(lex_vocab_s - etcsl_vocab_s)

# %%
print("number of words/expressions in ETCSL " + str(len(etcsl_vocab_s)))
print("number of words/expressions in lexical texts " + str(len(lex_vocab_s)))
print("number of words/expressions in ETCSL not in lexical " + str(len(diff_e_l)))
print("number of words/expressions in lexical not in ETCSL " + str(len(diff_l_e)))

# %%
plt.figure(figsize=(4,4))
venn2([etcsl_vocab_s, lex_vocab_s], ("literary", "lexical"))
plt.show()

# %% [markdown]
# # Rare Words Shared by Lex and Lit
# Which words appear in Lex and in Lit but appear only once in Lit? In which composition do we find such words; which words are those?
#
# First create a dataframe (`rare`) that only has the columns that add up to `1` (word or expression appears only once in the corpus). The row totals of this dataframe indicate per composition (= row) how many such rare words they contain. These row totals are added as a separate column. The composition naes are extracted from the `corpus` dataframe created above. Finally the dataframe is sorted by the row totals.
#
# The dataframe `rare` includes columns for each of the words that appear only once. We are showing only the columns that identify the composition and the row totals.

# %%
rare =etcsl_df.loc[:, etcsl_df.sum()==1].reset_index()
rare["no. of unique lexical correspondences"] = rare.sum(axis=1)
rare["text_name"] = corpus["text_name"]
rare = rare.sort_values('no. of unique lexical correspondences', ascending = False)
rare.loc[:,["etcsl_no", "no. of unique lexical correspondences", "text_name"]]

# %% [markdown]
# # Which Words?
# Which are the rare words that define this list of compositions? We first extract the full list of words from the column names of the daraframe `rare`. The variable `words` is a Numpy array that contains strings.

# %%
words = rare.columns.values
len(words)

# %% [markdown]
# # The rare words in the top-ten
# The first ten compositions in our list are the ones that have the most rare words shared with lexical texts. Each row, representing a composition, has columns that represent individual words. We create a `mask` (a sequence of boolean values `True` or `False`) that indicate whether or not the value in the column is 1. If the boolean is `True` the word is printed.

# %%
for i in range(10):
    indexes = rare.iloc[i] == 1
    print(rare.iloc[i,-1]), print(words[indexes])

# %%
lexical["text"] = lexical["text"].str.replace(" ", "*")
lexical

# %%
lexical_corpus = lexical.groupby([lexical["id_text"], 
                                  lexical["text_name"]]).aggregate({"text": " ".join}).reset_index()
lexical_corpus
