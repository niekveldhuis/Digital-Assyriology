# %%
# %pylab inline
from datascience import *
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import re
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Notes
#
# - Changed all [he, she] into [he/ she]
# - Changed all [itself, themselves] to [itself/ themselves]

# %%
with open('Enmerkar.txt', 'r') as text_file:
    enmerkar = text_file.read()

# %%
enmerkar_list = enmerkar.split(':')
enmerkar_list = [word for word in enmerkar_list if '[' in word]

# %%
etcsl_words = re.findall(r"(?<=\[)(.*?)(?=\])", enmerkar)
etcsl_words = [word for word in etcsl_words if word != '1']
etcsl_words
# Out:
# ['brick(work)',
#  '(mountain) land',
#  'shining',
#  'to go out or in',
#  'brick(work)',
#  'flat space',
#  'lapis lazuli',
#  'to go out or in',
#  'town',
#  'heaven',
#  'place',
#  'to grow',
#  'name',
#  'rainbow',
#  'heaven',
#  'to be adjacent',
#  'brilliance',
#  'to be multicoloured',
#  'heaven',
#  'to stand',
#  'crescent (moon)',
#  'to be new',
#  'to be',
#  'essence',
#  'to be big',
#  'princeliness',
#  'to erect',
#  '(mountain) land',
#  'to be pure',
#  'day(light)',
#  'to be good',
#  'place',
#  'to place',
#  'moon(light)',
#  'the Land',
#  'to go out or in',
#  'day(light)',
#  'to be shining',
#  'the Land',
#  'horn',
#  'to equal',
#  'rear cow',
#  'type of cow',
#  'abundance',
#  'to go out or in',
#  'mouth',
#  'to cut',
#  '(mountain) land',
#  'to approach',
#  '(awesome) radiance',
#  'bright metal',
#  'right',
#  'garment',
#  'to cover (together)',
#  'linen (fibre)',
#  'to release',
#  'day(light)',
#  'day(light)',
#  'lord',
#  'night',
#  'dais',
#  'king',
#  'minister',
#  'lord',
#  'minister',
#  'name',
#  'to be',
#  'minister',
#  'lord',
#  'name',
#  'lord',
#  'to be towering',
#  'he/ she',
#  'prince',
#  'to be towering',
#  'he/ she',
#  'lord',
#  'to be towering',
#  'he/ she',
#  'prince',
#  'to be towering',
#  'he/ she',
#  'lord',
#  'to be towering',
#  'he/ she',
#  'prince',
#  'to be towering',
#  'he/ she',
#  'person',
#  'deity',
#  'to give birth',
#  'he/ she',
#  'person',
#  'deity',
#  'branch',
#  'to go out or in',
#  'he/ she',
#  'lord',
#  'lord',
#  'that',
#  'contest',
#  'to say',
#  'lord',
#  'eye',
#  'eye',
#  'messenger',
#  'word',
#  'to say',
#  'he/ she',
#  'I',
#  'neck',
#  'to place',
#  'yoke',
#  'to raise',
#  'day(light)',
#  'neck',
#  'to place',
#  'neck',
#  'to place',
#  'and',
#  'he/ she',
#  'and',
#  'I',
#  'he/ she',
#  'wall',
#  'to live',
#  'I',
#  'to live',
#  'bed',
#  'blossom',
#  'to lie down',
#  'adornment',
#  'to say',
#  'sleep',
#  'to be good',
#  'to lay down',
#  'to lie down',
#  'he/ she',
#  'night',
#  'dream',
#  'eye',
#  'to spread',
#  'I',
#  'foot',
#  'white',
#  'word',
#  'to turn over',
#  'he/ she',
#  'goose',
#  'barley',
#  'to eat',
#  'I',
#  'goose',
#  'barley',
#  'to eat',
#  'I',
#  'goose',
#  'egg',
#  'basket',
#  'calf',
#  'to hang',
#  'to be small',
#  'tureen',
#  'to be big',
#  'type of vessel',
#  'to be majestic',
#  'goose',
#  'place',
#  'to leave behind',
#  '(city) ruler',
#  '(mountain) land',
#  'neck',
#  'to place',
#  'to eat',
#  'that',
#  'word',
#  'to say',
#  'messenger',
#  'to go',
#  'fallow deer?',
#  'to run',
#  'falcon',
#  'day(light)',
#  'to go out or in',
#  'evening',
#  'to return',
#  'sparrow?',
#  'day(light)',
#  'to pass',
#  'chest',
#  'place',
#  'side',
#  'to stand',
#  'sparrow?',
#  'night',
#  '1/2',
#  'centre of mountain',
#  'to fill',
#  'throwing stick',
#  'side',
#  'to stand',
#  'young donkey',
#  'single',
#  'to go',
#  'mountain (range)',
#  'to roam around',
#  'to split apart',
#  'young donkey',
#  'to be towering',
#  'to be big',
#  'noun part of multiword verb',
#  'to touch',
#  'young donkey',
#  'to be thin',
#  'to run',
#  'to seek',
#  'knee',
#  'to release',
#  'lion',
#  'field',
#  'day(light)',
#  'to pass',
#  'verb part of multiword verb',
#  'wolf',
#  'lamb',
#  'hand',
#  'to approach',
#  'to hasten',
#  'to go',
#  'place',
#  'to be small',
#  'to go',
#  'to fill',
#  'place',
#  'to be big',
#  'to go',
#  'sharp object',
#  'to say',
#  'lord',
#  'cloister',
#  'shining',
#  'place',
#  'shining',
#  'to enter',
#  'place',
#  'shining',
#  'to enter',
#  'you (sg.)',
#  'king',
#  'to return',
#  'lord',
#  'to return',
#  'king',
#  'to say',
#  'what is it to me',
#  'to add',
#  'what is it to me',
#  'to say',
#  'what is it to me',
#  'to add',
#  'what is it to me',
#  'king',
#  'what',
#  'to say',
#  'what',
#  'to add',
#  'what',
#  'to say',
#  'what',
#  'to add',
#  'king',
#  'to say',
#  'he/ she',
#  'I',
#  'neck',
#  'to place',
#  'yoke',
#  'to raise',
#  'day(light)',
#  'neck',
#  'to place',
#  'neck',
#  'to place',
#  'and',
#  'he/ she',
#  'and',
#  'I',
#  'he/ she',
#  'wall',
#  'to live',
#  'I',
#  'to live',
#  'bed',
#  'blossom',
#  'to lie down',
#  'adornment',
#  'to say',
#  'sleep',
#  'to be good',
#  'to lay down',
#  'to lie down',
#  'he/ she',
#  'night',
#  'dream',
#  'eye',
#  'to spread',
#  'I',
#  'foot',
#  'white',
#  'word',
#  'to turn over',
#  'he/ she',
#  'goose',
#  'barley',
#  'to eat',
#  'I',
#  'goose',
#  'barley',
#  'to eat',
#  'I',
#  'goose',
#  'egg',
#  'basket',
#  'calf',
#  'to hang',
#  'to be small',
#  'tureen',
#  'to be big',
#  'type of vessel',
#  'to be majestic',
#  'goose',
#  'place',
#  'to leave behind',
#  '(city) ruler',
#  '(mountain) land',
#  'neck',
#  'to place',
#  'to eat',
#  'lord',
#  'brilliance',
#  'rudder',
#  'shackle',
#  'hand',
#  'to direct',
#  'place',
#  'to be adjacent',
#  'falcon',
#  'heaven',
#  'to fly',
#  '(flax) thread',
#  'bird',
#  'brick(work)',
#  'house(hold)',
#  'to be big',
#  'to drip',
#  'to be majestic',
#  'to be big',
#  'destiny',
#  'to be majestic',
#  'DU',
#  'to be (located)',
#  'clay',
#  'hand',
#  'to beat',
#  'clay',
#  'eye',
#  'to set aside',
#  'he/ she',
#  'to live',
#  'I',
#  'heaven',
#  'place',
#  'to stand',
#  'to live',
#  'adornment',
#  'to say',
#  'sleep',
#  'to be good',
#  'to lay down',
#  'to lie down',
#  'I',
#  'bed',
#  'blossom',
#  'plant',
#  'lapis lazuli',
#  'dais',
#  'back',
#  'lion',
#  'head',
#  'lion',
#  'lion',
#  'lion',
#  'to run',
#  'lion',
#  'lion',
#  'to run',
#  'lion',
#  'lion',
#  'to run',
#  'lion',
#  'lion',
#  'to run',
#  'day(light)',
#  'to pass',
#  'night',
#  'designation of night',
#  'to face',
#  'I',
#  '(high)way',
#  'length measure',
#  '15',
#  'hand',
#  'to go around',
#  'crown',
#  'shining',
#  'eye',
#  'to set aside',
#  'cloister',
#  'shining',
#  'to enter',
#  'crown',
#  'right',
#  'sceptre',
#  'child',
#  'tree',
#  'waterskin',
#  'root',
#  'to be broad',
#  'sister',
#  'breast',
#  'right',
#  'to hang',
#  'breast',
#  'left (side)',
#  'to hang',
#  'shrine',
#  'to be big',
#  'to go down or up',
#  'high-status woman',
#  'calf',
#  'growl',
#  'verb part of multiword verb',
#  '2nd',
#  'to go down or up',
#  'duck',
#  'calf',
#  'to say',
#  'loud noise',
#  'to return',
#  'town',
#  'to give birth',
#  'town',
#  'to erect',
#  'town',
#  'any',
#  'to create',
#  'to live',
#  'what(ever)',
#  'to be',
#  'brick(work)',
#  'to live',
#  '(mountain) land',
#  'essence',
#  'to be pure',
#  'what',
#  'to do',
#  'year',
#  '5',
#  'year',
#  '10',
#  'to go',
#  'day(light)',
#  'to go',
#  'shining',
#  'to be big',
#  'lady',
#  'voice',
#  'to return',
#  'word',
#  'to know',
#  'to say',
#  'to go',
#  'he/ she',
#  'to have',
#  'goose',
#  'barley',
#  'to eat',
#  'I',
#  'goose',
#  'barley',
#  'to eat',
#  'I',
#  'goose',
#  'egg',
#  'basket',
#  'calf',
#  'to hang',
#  'to be small',
#  'tureen',
#  'to be big',
#  'type of vessel',
#  'to be majestic',
#  'goose',
#  'place',
#  'to leave behind',
#  '(city) ruler',
#  '(mountain) land',
#  'neck',
#  'to place',
#  'to eat',
#  'messenger',
#  'cloister',
#  'shining',
#  'place',
#  'shining',
#  'place',
#  'shining',
#  'KU',
#  'to approach',
#  'arm',
#  'to measure',
#  'voice',
#  'to pour',
#  'word',
#  'to seek',
#  'type of priest',
#  'type of priest',
#  'type of priest',
#  'attendant',
#  'cloister',
#  'to live',
#  'neck',
#  'to place',
#  'heart',
#  'to be tired',
#  'what',
#  'to say',
#  'what',
#  'to say',
#  'lord',
#  'lord',
#  'what',
#  'to say',
#  'bull',
#  'bull',
#  'clutching',
#  'to rise',
#  'bull',
#  'arm',
#  'to place',
#  'person',
#  'person',
#  'strength',
#  'to beat',
#  'person',
#  'arm',
#  'to place',
#  'man',
#  'man',
#  'strength',
#  'to beat',
#  'man',
#  'meaning unknown',
#  'to place',
#  'assembly',
#  'to place',
#  'horn',
#  'to equal',
#  'to return',
#  'you (sg.)',
#  'front (person)',
#  'thing',
#  'to be big',
#  'messenger',
#  'to return',
#  'to erect',
#  'you (sg.)',
#  'to erect',
#  'life (breath)',
#  'to return',
#  'heart',
#  'thing',
#  'any',
#  'to carry',
#  'as many as',
#  'to know',
#  'town',
#  'to cover (together)',
#  'to be',
#  'I',
#  '(pot)sherd',
#  'to be',
#  'lord',
#  'lord',
#  'neck',
#  'to place',
#  'sorcerer',
#  'reasoning',
#  'child',
#  'reasoning',
#  'child',
#  'to be bad',
#  'to turn over',
#  "sorcerer's craft",
#  '(sleeping) chamber',
#  'KU',
#  'minister',
#  'voice',
#  'to pour',
#  'king',
#  'father',
#  'to be big',
#  'town',
#  'to be old',
#  'foundation',
#  'place',
#  'to place',
#  'why',
#  'to place',
#  'voice',
#  'to return',
#  'I',
#  'watercourse',
#  'to dig',
#  '(sleeping) chamber',
#  'neck',
#  'to place',
#  'word',
#  'to touch',
#  'group of people',
#  'to be big',
#  'to be low',
#  'upper land',
#  'sea',
#  '(mountain) land',
#  'cedar',
#  'upper land',
#  '(mountain) land',
#  'aromatic (fragrance)',
#  'cedar',
#  'neck',
#  'to place',
#  'possessions',
#  'itself/ themselves',
#  'boat',
#  'to be long',
#  'boat',
#  'to hang',
#  'minister',
#  'town',
#  'to rise',
#  'to fall',
#  'person',
#  'to say',
#  'X',
#  'king',
#  'father',
#  'to be big',
#  'town',
#  'to be old',
#  'foundation',
#  'place',
#  'to place',
#  'place',
#  'minister',
#  'palace',
#  'why',
#  'to place',
#  'voice',
#  'to return',
#  'I',
#  'watercourse',
#  'to dig',
#  '(sleeping) chamber',
#  'neck',
#  'to place',
#  'word',
#  'to touch',
#  'group of people',
#  'to be big',
#  'to be low',
#  'upper land',
#  'sea',
#  '(mountain) land',
#  'cedar',
#  'upper land',
#  '(mountain) land',
#  'aromatic (fragrance)',
#  'cedar',
#  'neck',
#  'to place',
#  'possessions',
#  'itself/ themselves',
#  'boat',
#  'to be long',
#  'boat',
#  'to hang',
#  'lord',
#  'to be happy',
#  'to place',
#  '5',
#  'weight measure',
#  'gold',
#  'to give',
#  '5',
#  'weight measure',
#  'silver',
#  'to give',
#  'plant',
#  'authoritative',
#  'to eat',
#  'to allot',
#  'to say',
#  'water',
#  'authoritative',
#  'to drink',
#  'to allot',
#  'to say',
#  'day(light)',
#  'booty',
#  'person',
#  'to do',
#  'life (breath)',
#  'thing',
#  'exuberance',
#  'hand',
#  'plenty',
#  'to say',
#  'sorcerer',
#  'farmer',
#  'seed',
#  'head',
#  'town',
#  'foot',
#  'to stand',
#  'animal stall',
#  'house(hold)',
#  'cow',
#  'to sit',
#  'to approach',
#  'cow',
#  'animal stall',
#  'head',
#  'to beat',
#  'cow',
#  'word',
#  'to say',
#  'person',
#  'word',
#  'to turn over',
#  'cow',
#  'to know',
#  'who',
#  'to eat',
#  'to know',
#  'who',
#  'to drink',
#  'fatty substance',
#  'to eat',
#  'milk',
#  'to drink',
#  'cheese',
#  'crown',
#  'shining',
#  'to be skilful',
#  'to say',
#  '(dining) hall',
#  'to be big',
#  '(dining) hall',
#  '(fitting) attribute',
#  'to be (located)',
#  'fatty substance',
#  'animal stall',
#  'shining',
#  'extent',
#  'to carry',
#  'milk',
#  'sheepfold',
#  'shining',
#  'extent',
#  'to carry',
#  'wild cow?',
#  'right',
#  'first-born (child)',
#  'person',
#  'to rise',
#  'cow',
#  'to know',
#  'brilliance',
#  'to know',
#  'back',
#  'cow',
#  'fatty substance',
#  'brilliance',
#  'BU',
#  'milk',
#  'back',
#  'BU',
#  'foot',
#  'sheepfold',
#  'shining',
#  'sheepfold',
#  'to approach',
#  '(nanny) goat',
#  'sheepfold',
#  'head',
#  'to beat',
#  '(nanny) goat',
#  'word',
#  'to say',
#  'person',
#  'word',
#  'to turn over',
#  '(nanny) goat',
#  'to know',
#  'who',
#  'to eat',
#  'to know',
#  'who',
#  'to drink',
#  'fatty substance',
#  'to eat',
#  'milk',
#  'to drink',
#  'cheese',
#  'crown',
#  'shining',
#  'to be skilful',
#  'to say',
#  '(dining) hall',
#  'to be big',
#  '(dining) hall',
#  '(fitting) attribute',
#  'to be (located)',
#  'fatty substance',
#  'animal stall',
#  'shining',
#  'extent',
#  'to carry',
#  'milk',
#  'sheepfold',
#  'shining',
#  'extent',
#  'to carry',
#  'wild cow?',
#  'right',
#  'first-born (child)',
#  'person',
#  'to rise',
#  '(nanny) goat',
#  'to know',
#  'brilliance',
#  'to know',
#  'back',
#  '(nanny) goat',
#  'fatty substance',
#  'brilliance',
#  'BU',
#  'milk',
#  'back',
#  'to go out or in',
#  'day(light)',
#  'animal stall',
#  'sheepfold',
#  'house(hold)',
#  'to be silent',
#  'to say',
#  'thing',
#  'to be lost',
#  'to do',
#  'breast',
#  'cow',
#  'milk',
#  'to be (located)',
#  'calf',
#  'day(light)',
#  'to cover',
#  'calf',
#  'to be small',
#  'emptiness',
#  'to be (located)',
#  'tear',
#  'to be ill',
#  'to weep',
#  'breast',
#  '(nanny) goat',
#  'milk',
#  'to be (located)',
#  '(kid) goat',
#  'day(light)',
#  'to cover',
#  'breeding goat',
#  'fasting',
#  'to lie down',
#  'life (breath)',
#  'cow',
#  'calf',
#  'word',
#  'to be ill',
#  'to say',
#  '(nanny) goat',
#  '(kid) goat',
#  'churn',
#  'shining',
#  'to be silent',
#  'emptiness',
#  'to be (located)',
#  'fasting',
#  'to lie down',
#  'day(light)',
#  'animal stall',
#  'sheepfold',
#  'house(hold)',
#  'to be silent',
#  'to say',
#  'thing',
#  'to be lost',
#  'to do',
#  'herdsman',
#  'staff',
#  'hand',
#  'to leave behind',
#  'eye',
#  'to beat',
#  'shepherd',
#  "shepherd's crook",
#  'side',
#  'to hang',
#  'tear',
#  'to be ill',
#  'to weep',
#  'junior shepherd',
#  'to be small',
#  'sheepfold',
#  'animal stall',
#  'foot',
#  'to be different',
#  'to seize',
#  'milk carrier',
#  'voice',
#  'to be big',
#  'to go down or up',
#  'street',
#  'to be different',
#  'to seize',
#  'herdsman',
#  'shepherd',
#  'child',
#  'to give birth',
#  'mother',
#  'single',
#  'animal stall',
#  'sheepfold',
#  'arm',
#  'to go out or in',
#  '1st',
#  'name',
#  'to be',
#  '2nd',
#  'name',
#  'to be',
#  '2',
#  'gate',
#  'to be majestic',
#  'eye',
#  'to go out or in',
#  'place',
#  'wonder',
#  'to say',
#  'the Land',
#  'debris',
#  'to sit',
#  'heaven',
#  'to return',
#  'sorcerer',
#  'person',
#  'animal stall',
#  'to enter',
#  'animal stall',
#  'cream',
#  'to be rare',
#  'calf',
#  'to be small',
#  'to direct',
#  'animal stall',
#  'sheepfold',
#  'abomination',
#  'to do',
#  'fatty substance',
#  'milk',
#  'to be rare',
#  'to hang',
#  'to hang',
#  'milk',
#  '(nanny) goat',
#  'to be rare',
#  'to fall',
#  'thing',
#  'to be lost',
#  'to do',
#  ...]

# %%
Enmerkar_table = Table.read_table('Enmerkar.txt', sep = ',')
Enmerkar_table = Enmerkar_table.drop(['text_name', 'etcsl_no'])
Enmerkar_table
# Out:
#  text_name                 |  l_no |  text
# Enmerkar and En-suhgir-ana | 1     | sux:šeg₁₂[brick(work)]N sux:kur[(mountain) land]N sux:šu ...
# Enmerkar and En-suhgir-ana | 2     | sux:Kulaba[1]SN sux:iri[town]N sux:an[heaven]N sux:ki[pl ...
# Enmerkar and En-suhgir-ana | 3     | sux:Unug[1]SN sux:mu[name]N sux:tir-an-na[rainbow]N
# Enmerkar and En-suhgir-ana | 4     | sux:an[heaven]N sux:us₂[to be adjacent]V sux:si-muš₃[bri ...
# Enmerkar and En-suhgir-ana | 5     | sux:an[heaven]N sux:gub[to stand]V sux:ud-sakar[crescent ...
# Enmerkar and En-suhgir-ana | 6     | sux:me[essence]N sux:gal[to be big]V sux:nam-nun[princel ...
# Enmerkar and En-suhgir-ana | 7     | sux:kur[(mountain) land]N sux:sikil[to be pure]V sux:ud[ ...
# Enmerkar and En-suhgir-ana | 8     | sux:itid[moon(light)]N sux:kalam[the Land]N sux:e₃[to go ...
# Enmerkar and En-suhgir-ana | 9     | sux:ud[day(light)]N sux:zalag[to be shining]V sux:kalam[ ...
# Enmerkar and En-suhgir-ana | 10    | sux:ab₂-ur₃[rear cow]N sux:ab₂-saharₓ[type of cow]N sux: ...
# ... (285 rows omitted)

# %%
def remove_space_from_labels(table):
    for label in table.labels:
        table.relabel(label, label.replace(' ', ''))
    return table

Enmerkar_table = remove_space_from_labels(Enmerkar_table)

# %%
#drop rows of different translations
to_be_dropped = []
for i in Enmerkar_table['l_no']:
    if re.search('[a-zA-Z]', i):
        to_be_dropped.append(False)
    else:
        to_be_dropped.append(True)
Enmerkar_table = Enmerkar_table.where(to_be_dropped)

Enmerkar_table.labels
# Out:
# ('text_name', 'l_no', 'text')

# %%
proper_nouns = {
'CN': 'Constellation Name (star)',
'DN': 'Deity Name',
'EN': 'Ethnicity Name',
'FN': 'Field Name',
'GN': 'Geographical Name (for regions and countries)',
'MN': 'Month Name',
'ON': 'Object Name (usually for objects associated with a god)',
'PN': 'Personal Name',
'RN': 'Royal Name',
'SN': 'Settlement Name',
'TN': 'Temple Name',
'WN': 'Water Name',
}

simple_terms = {
    'AJ': 'Adjective',
    'AV': 'Adverb',
    'C': 'Conjunction',
    'N': 'Noun',
    'NU': 'Number',
    'PD': 'Part of Speech',
    'V': 'Verb',
}

# %%
def term_finder (line):
    #returns the meanings of words in a line of text
    terms = re.findall(r"(?<=\[)(.*?)(?=\])", line)
    return terms

def proper_noun_finder(line):
    #returns a list of all the proper nouns in a line of text
    nouns = re.findall(r"(?<=\:)(.*?)(?=\[)", line)
    nouns = [word for word in nouns if (len(word) > 1 and word[0].isupper() and not word[1].isupper())]
    return nouns

def speech_article_finder(line, proper_noun_filter = True):
    #returns the speech articles for proper_nouns or all words
    terms = re.findall(r"(?<=\])(.*?)(?=\s)", line)
    if proper_noun_filter:
        articles = [term for term in terms if term in proper_nouns]
    else: 
        articles = terms
    return articles

# %%
Enmerkar_table = Enmerkar_table.with_columns([
    'terms', Enmerkar_table.apply(term_finder, 'text'), 
    'proper_nouns', Enmerkar_table.apply(proper_noun_finder, 'text'), 
    'speech_articles', Enmerkar_table.apply(speech_article_finder, 'text')
    ])

Enmerkar_table.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>text_name</th> <th>l_no</th> <th>text</th> <th>terms</th> <th>proper_nouns</th> <th>speech_articles</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>1   </td> <td>sux:šeg₁₂[brick(work)]N sux:kur[(mountain) land]N sux:šu ...</td> <td>['brick(work)', '(mountain) land', 'shining', 'to go out ...</td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>2   </td> <td>sux:Kulaba[1]SN sux:iri[town]N sux:an[heaven]N sux:ki[pl ...</td> <td>['1', 'town', 'heaven', 'place', 'to grow']                 </td> <td>['Kulaba']                           </td> <td>['SN']            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>3   </td> <td>sux:Unug[1]SN sux:mu[name]N sux:tir-an-na[rainbow]N         </td> <td>['1', 'name', 'rainbow']                                    </td> <td>['Unug']                             </td> <td>['SN']            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>4   </td> <td>sux:an[heaven]N sux:us₂[to be adjacent]V sux:si-muš₃[bri ...</td> <td>['heaven', 'to be adjacent', 'brilliance', 'to be multic ...</td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>5   </td> <td>sux:an[heaven]N sux:gub[to stand]V sux:ud-sakar[crescent ...</td> <td>['heaven', 'to stand', 'crescent (moon)', 'to be new', ' ...</td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>6   </td> <td>sux:me[essence]N sux:gal[to be big]V sux:nam-nun[princel ...</td> <td>['essence', 'to be big', 'princeliness', 'to erect']        </td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>7   </td> <td>sux:kur[(mountain) land]N sux:sikil[to be pure]V sux:ud[ ...</td> <td>['(mountain) land', 'to be pure', 'day(light)', 'to be g ...</td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>8   </td> <td>sux:itid[moon(light)]N sux:kalam[the Land]N sux:e₃[to go ...</td> <td>['moon(light)', 'the Land', 'to go out or in']              </td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>9   </td> <td>sux:ud[day(light)]N sux:zalag[to be shining]V sux:kalam[ ...</td> <td>['day(light)', 'to be shining', 'the Land', 'horn', 'to  ...</td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>10  </td> <td>sux:ab₂-ur₃[rear cow]N sux:ab₂-saharₓ[type of cow]N sux: ...</td> <td>['rear cow', 'type of cow', 'abundance', 'to go out or in'] </td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>11  </td> <td>sux:Unug[1]SN sux:ka[mouth]N sux:tar[to cut]V sux:kur[(m ...</td> <td>['1', 'mouth', 'to cut', '(mountain) land', 'to approach']  </td> <td>['Unug']                             </td> <td>['SN']            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>12  </td> <td>sux:me-lem₄[(awesome) radiance]N sux:kug-me-a[bright met ...</td> <td>['(awesome) radiance', 'bright metal', 'right']             </td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>13  </td> <td>sux:Aratta[1]SN sux:tug₂[garment]N sux:dul[to cover (tog ...</td> <td>['1', 'garment', 'to cover (together)', 'linen (fibre)', ...</td> <td>['Aratta']                           </td> <td>['SN']            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>14  </td> <td>sux:ud[day(light)]N sux:ud[day(light)]N sux:en[lord]N su ...</td> <td>['day(light)', 'day(light)', 'lord', 'night', 'dais', '1 ...</td> <td>['Utu']                              </td> <td>['DN']            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>15  </td> <td>sux:sukkal[minister]N sux:en[lord]N sux:Aratta[1]SN sux: ...</td> <td>['minister', 'lord', '1', 'minister', '1', 'name', 'to be'] </td> <td>['Aratta', 'Ansiga-ria']             </td> <td>['SN', 'PN']      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>16  </td> <td>sux:sukkal[minister]N sux:Enmerkar[1]RN sux:en[lord]N su ...</td> <td>['minister', '1', 'lord', '1', '1', 'name']                 </td> <td>['Enmerkar', 'Kulaba', 'Namena-tuma']</td> <td>['RN', 'SN', 'PN']</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>17  </td> <td>sux:en[lord]N sux:uru₁₆[to be towering]V sux:e-ne[he/ sh ...</td> <td>['lord', 'to be towering', 'he/ she', 'prince', 'to be t ...</td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>18  </td> <td>sux:en[lord]N sux:uru₁₆[to be towering]V sux:e-ne[he/ sh ...</td> <td>['lord', 'to be towering', 'he/ she', 'prince', 'to be t ...</td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>19  </td> <td>sux:en[lord]N sux:uru₁₆[to be towering]V sux:e-ne[he/ sh ...</td> <td>['lord', 'to be towering', 'he/ she', 'prince', 'to be t ...</td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>20  </td> <td>sux:lu₂[person]N sux:diŋir[deity]N sux:tud[to give birth ...</td> <td>['person', 'deity', 'to give birth', 'he/ she']             </td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>21  </td> <td>sux:lu₂[person]N sux:diŋir[deity]N sux:pa[branch]N sux:e ...</td> <td>['person', 'deity', 'branch', 'to go out or in', 'he/ she'] </td> <td>[]                                   </td> <td>[]                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>22  </td> <td>sux:en[lord]N sux:Unug[1]SN sux:en[lord]N sux:Kulaba[1]S ...</td> <td>['lord', '1', 'lord', '1', 'that', 'contest', 'to say']     </td> <td>['Unug', 'Kulaba']                   </td> <td>['SN', 'SN']      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>23  </td> <td>sux:en[lord]N sux:Aratta[1]SN sux:En-suhgir-ana[1]RN        </td> <td>['lord', '1', '1']                                          </td> <td>['Aratta', 'En-suhgir-ana']          </td> <td>['SN']            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>24  </td> <td>sux:igi[eye]N sux:igi[eye]N sux:Unug[1]SN sux:kiŋ₂-gi₄-a ...</td> <td>['eye', 'eye', '1', 'messenger', 'word', 'to say']          </td> <td>['Unug']                             </td> <td>['SN']            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Enmerkar and En-suhgir-ana</td> <td>25  </td> <td>sux:e-ne[he/ she]PD sux:ŋe₂₆[I]PD sux:gu₂[neck]N sux:ŋar ...</td> <td>['he/ she', 'I', 'nec

# %%
def partitioning(line_no):
    
    #ln = int(''.join(c for c in line_no if c.isdigit()))
    ln = int(line_no)
    if(ln <= 13):
        return "1.1"
    elif (ln <= 21):
        return "1.2"
    
    elif (ln <= 39):
        return "2.1.1"
    elif (ln <= 51):
        return "2.1.2"
    elif (ln <= 69):
        return "2.1.3"
    
    elif (ln <= 76):
        return "2.2.1"
    elif (ln <= 90):
        return "2.2.2"
    elif (ln <= 113):
        return "2.2.3"
    
    elif (ln <= 127):
        return "2.3.1"
    elif (ln <= 132):
        return "2.3.2"
    elif (ln <= 134):
        return "2.3.3"
    
    elif (ln <= 138):
        return "3.1.1"
    elif (ln <= 149):
        return "3.1.2"
    elif (ln <= 162):
        return "3.1.3"
    elif (ln <= 169):
        return "3.1.4"
    
    elif (ln <= 184):
        return "3.2.1"
    elif (ln <= 197):
        return "3.2.2"
    elif (ln <= 205):
        return "3.2.3"
    elif (ln <= 210):
        return "3.2.4"
    elif (ln <= 221):
        return "3.2.5"
    
    elif (ln <= 227):
        return "4.1"
    
    elif (ln <= 248):
        return "4.2.1"
    elif (ln <= 254):
        return "4.2.2"
    elif (ln <= 263):
        return "4.2.3"
    elif (ln <= 273):
        return "4.2.4"
    
    elif (ln <= 280):
        return "5.1"
    elif (ln <= 283):
        return "5.2"
    elif (ln <= 310):
        return "B"
    return "0"

def small_partition(line_no):
    #ln = int(''.join(c for c in line_no if c.isdigit()))
    ln = int(line_no)
    if(ln <= 13):
        return "1.1"
    elif (ln <= 21):
        return "1.2"
    elif (ln <= 69):
        return "2.1"
    elif (ln <= 113):
        return "2.2"
    elif (ln <= 134):
        return "2.3"
    elif (ln <= 169):
        return "3.1"
    elif (ln <= 221):
        return "3.2"
    elif (ln <= 227):
        return "4.1"
    elif (ln <= 273):
        return "4.2"
    elif (ln <= 280):
        return "5.1"
    elif (ln <= 283):
        return "5.2"
    elif (ln <= 310):
        return "6"
    return "0"

# %%
Enmerkar_table.append_column('section', Enmerkar_table.apply(partitioning, 'l_no'))
Enmerkar_graph = Enmerkar_table.select(['proper_nouns', 'speech_articles', 'section']).group('section', list)
Enmerkar_graph
# Out:
# section | proper_nouns list                                            | speech_articles list
# 1.1     | [[], ['Kulaba'], ['Unug'], [], [], [], [], [], [], [], [ ... | [[], ['SN'], ['SN'], [], [], [], [], [], [], [], ['SN'], ...
# 1.2     | [['Utu'], ['Aratta', 'Ansiga-ria'], ['Enmerkar', 'Kulaba ... | [['DN'], ['SN', 'PN'], ['RN', 'SN', 'PN'], [], [], [], [ ...
# 2.1.1   | [['Unug', 'Kulaba'], ['Aratta', 'En-suhgir-ana'], ['Unug ... | [['SN', 'SN'], ['SN'], ['SN'], [], [], ['DN'], ['DN', 'T ...
# 2.1.2   | [[], [], [], [], [], ['Šakkan'], [], [], [], [], [], []]     | [[], [], [], [], [], ['DN'], [], [], [], [], [], []]
# 2.1.3   | [[], [], ['Aratta', 'En-suhgir-ana'], [], [], [], ['Inan ... | [[], [], ['SN', 'RN'], [], [], [], ['DN'], ['DN', 'TN',  ...
# 2.2.1   | [['Unug'], [], [], [], ['Aratta'], ['Aratta'], []]           | [['SN'], [], [], [], ['SN'], ['SN'], []]
# 2.2.2   | [[], ['Inana', 'E-zagin', 'Aratta'], [], [], ['Inana'],  ... | [[], ['DN', 'TN', 'SN'], [], [], ['DN'], [], [], [], [], ...
# 2.2.3   | [['Enlil'], ['Ninurta', 'Enlil'], [], ['Aruru', 'Enlil'] ... | [['DN'], ['DN'], [], ['DN'], [], [], ['DN'], [], [], [], ...
# 2.3.1   | [['Enmerkar', 'En-suhgir-ana'], [], [], ['En-suhgir-ana' ... | [['RN'], [], [], ['RN'], [], [], [], ['SN', 'SN'], [], [ ...
# 2.3.2   | [[], ['Unug'], ['Enmerkar'], ['Enmerkar'], []]               | [[], ['SN'], ['RN'], ['RN'], []]
# ... (18 rows omitted)

# %%
def list_flattening(pn_list):
    return [noun for nouns in pn_list for noun in nouns]

Enmerkar_graph.append_column('speech articles', Enmerkar_graph.apply(list_flattening, 'speech_articles list'))
Enmerkar_graph.append_column('proper nouns', Enmerkar_graph.apply(list_flattening, 'proper_nouns list'))
Enmerkar_graph = Enmerkar_graph.drop(['proper_nouns list', 'speech_articles list'])
Enmerkar_graph
# Out:
# section | speech articles                                              | proper nouns
# 1.1     | ['SN', 'SN', 'SN', 'SN']                                     | ['Kulaba', 'Unug', 'Unug', 'Aratta']
# 1.2     | ['DN', 'SN', 'PN', 'RN', 'SN', 'PN']                         | ['Utu', 'Aratta', 'Ansiga-ria', 'Enmerkar', 'Kulaba', 'N ...
# 2.1.1   | ['SN', 'SN', 'SN', 'SN', 'DN', 'DN', 'TN', 'SN', 'DN', ' ... | ['Unug', 'Kulaba', 'Aratta', 'En-suhgir-ana', 'Unug', 'I ...
# 2.1.2   | ['DN']                                                       | ['Šakkan']
# 2.1.3   | ['SN', 'RN', 'DN', 'DN', 'TN', 'SN', 'DN', 'DN']             | ['Aratta', 'En-suhgir-ana', 'Inana', 'Inana', 'E-zagin', ...
# 2.2.1   | ['SN', 'SN', 'SN']                                           | ['Unug', 'Aratta', 'Aratta']
# 2.2.2   | ['DN', 'TN', 'SN', 'DN', 'DN', 'DN']                         | ['Inana', 'E-zagin', 'Aratta', 'Inana', 'Inana', 'Utu']
# 2.2.3   | ['DN', 'DN', 'DN', 'DN', 'DN', 'SN', 'SN', 'SN', 'SN', ' ... | ['Enlil', 'Ninurta', 'Enlil', 'Aruru', 'Enlil', 'Anzud', ...
# 2.3.1   | ['RN', 'RN', 'SN', 'SN', 'SN', 'SN', 'SN']                   | ['Enmerkar', 'En-suhgir-ana', 'En-suhgir-ana', 'Unug', ' ...
# 2.3.2   | ['SN', 'RN', 'RN']                                           | ['Unug', 'Enmerkar', 'Enmerkar']
# ... (18 rows omitted)

# %%
def partitioner (i):
    rows = []
    section = Enmerkar_graph['section'][i]
    speech_articles = Enmerkar_graph['speech articles'][i]
    proper_nouns = Enmerkar_graph['proper nouns'][i]
    #for j in range(len(speech_articles)):
    #    article = speech_articles[j]
    #    proper_noun = proper_nouns[j]
    #    rows.append([section, article, proper_noun])
    for j, item in enumerate(speech_articles):
        article = item
        proper_noun = proper_nouns[j]
        rows.append([section, article, proper_noun])
    return rows

Enmerkar_table_section = Table(['section', 'speech articles', 'proper nouns'])
for i in range(Enmerkar_graph.num_rows):
    Enmerkar_table_section = Enmerkar_table_section.with_rows(partitioner(i))
Enmerkar_table_section
# Out:
# section | speech articles | proper nouns
# 1.1     | SN              | Kulaba
# 1.1     | SN              | Unug
# 1.1     | SN              | Unug
# 1.1     | SN              | Aratta
# 1.2     | DN              | Utu
# 1.2     | SN              | Aratta
# 1.2     | PN              | Ansiga-ria
# 1.2     | RN              | Enmerkar
# 1.2     | SN              | Kulaba
# 1.2     | PN              | Namena-tuma
# ... (116 rows omitted)

# %%
proper_noun_by_section = Enmerkar_table_section.pivot('proper nouns', rows = 'section')
name_counts = []
for name in proper_noun_by_section.drop('section').labels:
    name_counts.append([name, np.sum(proper_noun_by_section[name])])
top_7_names = ['Aratta', 'En-suhgir-ana', 'Enmerkar', 'Inana', 'Nisaba', 'Saŋburu', 'Unug']

# %%
names_section_graph = proper_noun_by_section.with_column(
    'section', range(1, proper_noun_by_section.num_rows+1))

aratta_unug_section_graph = names_section_graph.select(['Aratta', 'Unug', 'section']).plot('section')
#notice Aratta is the only one mentioned in the section 4.2.3

# %%
top_7_names_graph = names_section_graph.select(top_7_names + ['section']).plot('section')

# %%
names_section_graph.plot('section')

# %% [markdown]
# ### Plot character arcs by line number

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %%
def noun_counts(noun, proper_nouns):
    noun_count = []
    for i in np.arange(len(proper_nouns)):
        noun_count.append(proper_nouns[i].count(noun))
    return noun_count

# %%
names_cumulative_graph = Enmerkar_table.select(['l_no', 'proper_nouns'])
unique_nouns = np.sort(list(set(list_flattening(names_cumulative_graph.column('proper_nouns')))))
for i in np.arange(1, len(unique_nouns)+1):
    current_noun = unique_nouns[i-1]
    names_cumulative_graph.append_column(current_noun, np.cumsum(noun_counts(current_noun, names_cumulative_graph.column('proper_nouns'))))

names_cumulative_graph = names_cumulative_graph.drop('proper_nouns')

# %%
def plot(name, graph, prefix):
    if name != 'None':
        line_graph = graph.select([prefix] + [name])
        plt.plot(line_graph[0], line_graph[1])
        
def plot_cumulative_characters(name1, name2, name3, name4):
        plot(name1, names_cumulative_graph, 'l_no')
        plot(name2, names_cumulative_graph, 'l_no')
        plot(name3, names_cumulative_graph, 'l_no')
        plot(name4, names_cumulative_graph, 'l_no')
        
def plot_section_characters(name1, name2, name3, name4):
        plot(name1, names_section_graph, 'section')
        plot(name2, names_section_graph, 'section')
        plot(name3, names_section_graph, 'section')
        plot(name4, names_section_graph, 'section')
    
unique_nouns = tuple(['None'] + list(unique_nouns))

# %%
interact(plot_cumulative_characters, name1=unique_nouns, name2=unique_nouns, name3=unique_nouns, name4=unique_nouns)

# %%
interact(plot_section_characters, name1=unique_nouns, name2=unique_nouns, name3=unique_nouns, name4=unique_nouns)
