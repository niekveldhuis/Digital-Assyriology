# %% [markdown]
# # TODO
# The scraper output needs a field 'version' to make it compatible with ETCSL output. This field may be used for pseudo-composites such as [dcclt/Q000043](http://oracc.org/dcclt/Q000043) to indicate the designation of the tablet from which the text is taken.

# %% [markdown]
# # ORACC Scraper
#
# Generalized scraper for [ORACC](html://oracc.org) files. The scraper needs an input file, that lists the P, Q, or X numbers to be scraped. It will create an output file for each of these P, Q, or X numbers with line numbers and lemmatized words.

# %% [markdown]
# ## Set up the environment
# Import the packages:
# - re Regular Expressions (for string manipulation)
# - BeautifulSoup (for parsing HTML pages)
# - tqdm for progress bar
# This scraper is written for Python3.

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#! pip install tqdm
from __future__ import print_function
from bs4 import BeautifulSoup
import re
import sys
import os
import ipywidgets as widgets
from time import sleep
from tqdm import *
from ipywidgets import Checkbox, interactive
from IPython.display import display

#this program should use python unit test
PY3 = sys.version_info.major == 3

if not PY3:
    input = raw_input

print("Running under Python version:", sys.version_info[:3])
# Out:
# Running under Python version: (3, 5, 2)

# %% [markdown]
# ## Format Output Options
# - Select output variables by checking the box next to the variable.
# - To provide optional values to filter by for the selected variables, type the desired value in the text box.
# - The default output is "lang:citform[guide]pos", so those 4 options are initially checked. The text fields are initially empty, so there are no restrictions (nothing is filtered out). You can check and uncheck any of the options, as well as provide values to filter the output by.
# - Example 1: If we only want nouns, make sure pos is checked, and type in 'N' in the text field next to pos.
# - Example 2: If we only want nouns that are in Sumerian, make sure lang and pos are checked, and type in 'sux' for lang and 'N' for pos. This will only output text that is both in Sumerian and a noun.

# %%
l = ["lang", "translit", "citform", "guide", "sense", "pos", "epos", "norm", "base", "morph"]
checks = [widgets.Checkbox(description=a) for a in l]
inputs = [widgets.Text(description="") for a in l]
for c in checks:
    if c.description in ['lang', 'citform', 'guide', 'pos']:
        c.value = True
        
checkboxes = widgets.VBox(checks)
inputboxes = widgets.VBox(inputs)
combined_check_input = widgets.HBox([checkboxes, inputboxes])
display(combined_check_input)

# %%
textiderror = 'Not available:\n'

# %% [markdown]
# # Input File
#
# The input file should be located in a directory called /Input, which must be located in the directory in which this Python Notebook is found. The file should have a .txt extension and must be created with a flat text editor such as TextEdit, Notepad, or Emacs. The file contains a simple list of P, Q, or X numbers, preceded by the ORACC abbreviation where the file is edited. For instance:
#
#     rinap/rinap1/Q003421
#     dcclt/Q000039
#     cams/gkab/P348623
#
# Before running this scraper, use the same input file to download the text material (in html format) with the ORACC Downloader to the /Data directory.

# %%
inputfile = input("Name of Input List: ")
# Out:
# Name of Input List: ob-lex.txt

# %% [markdown]
# # Format Output
#
# The function outputformat() defines what the output of the lemmatized forms will look like. This function may be adapted in various ways to produce different types of output. The function takes a dictionary as input with the following keys:
#
# - 1     lang: Language
# - 2     translit: Transliteration
# - 3     citform: Citation Form
# - 4     guideword: Guide Word
# - 5     sense: Sense
# - 6     pos: Part of Speech
# - 7     epos: Effective Part of Speech
# - 8     norm: Normalization
# - 9     base: Base (Sumerian only)
# - 10    morph: Morphology (Sumerian only)
#
# In the standard format the output will look like: sux:lugal[king]N. One may adapt the output, for instance, by omitting the element lang (lugal[king]N) or to select for certain parts of speech, or for certain language codes. For instance:
# ```python
#     if output['pos'] == 'N':
#         output_formatted = output['citform'] + "\t" + output['guide']
# ```
# This will create output in the form lugal   king (lugal and king seperated by TAB), selecting only Nouns (excluding Proper Nouns).
#
# ```python
#     if output['lang'] == 'sux-x-emesal':
#         output_formatted = output['citform'] + "[" + output['guide'] + "]" + output['pos']
# ```
# This will create output in the form umun[lord]N, selecting only Emesal words.
# In order to select both Sumerian (sux) and Emesal (sux-x-emesal) forms one could use:
# Jason's comment: How about give a list of outputs you want. Like sux, sux-x-emesal.
# ```python
#     if output['lang'][0:3] == 'sux':
# ```

# %% [markdown]
# This code may be used (instead of the next cell) to only return proper nouns in the format CF[GW]POS:
# `def outputformat(output):
#     #output_formatted = ''
#     QPN = ('AN', 'CN', 'DN', 'EN', 'FN', 'GN', 'LN', 'MN', 'ON', 'PN', 'QN', 'RN', 'SN', 'TN', 'WN', 'YN')
#     if output['pos'] in QPN:
#         output_formatted = output['citform'] + "[" + output['guideword'] + "]" + output['pos']
#     else:
#         return None
#     return output_formatted`

# %%
QPN = ('AN', 'CN', 'DN', 'EN', 'FN', 'GN', 'LN', 'MN', 'ON', 'PN', 'QN', 'RN', 'SN', 'TN', 'WN', 'YN')
options_selected = [(c.description, inputs[checks.index(c)].value) for c in checks if c.value]
restrictions = [(checks[inputs.index(i)].description, i.value) for i in inputs if i.value != '']

## Or Statement, outputs if it matches any of the text fields
def conformsOr(output, restrictions):
    for r in restrictions:
        if output[r[0]] == r[1]:
            return True
        if r[0] == 'pos' and r[1] == 'QPN' and output['pos'] in QPN:
            return True
    return False

## And Statement, outputs only if it matches all of the text fields
def conforms(output, restrictions):
    for r in restrictions:
        if r[0] == 'pos' and r[1] == 'QPN' and output['pos'] in QPN:
            continue
        if output[r[0]] != r[1]:
            return False
    return True
    
def outputformat(output):
    if conforms(output, restrictions):
        output_formatted = ''
        for options in options_selected:
            if options[0] == 'guide':
                output_formatted += "["
            output_formatted += output[options[0]]
            if options[0] == 'lang':
                output_formatted += ":"
            if options[0] == 'guide':
                output_formatted += "]"
        print(output_formatted)
        return output_formatted
    else:
        return None

def outputformatold(output):
    output_formatted = ''
    if True:
        output_formatted = output['lang'] + ":" + output['citform'] + "[" + output['guide'] + "]" + output['pos']
    else:
        return None
    return output_formatted

# %% [markdown]
# # Parse an ORACC lemma
#
# The function `parselemma()` parses a so-called ORACC 'signature.' It is called by the `getline()` function where these signatures are extracted from the html files. A signature, as extracted by the `getline()` function, looks as follows:
#
# > javascript:pop1sig('dcclt','','@dcclt%sux:am-si=amsi[elephant//elephant]N´N$amsi/am-si#~').
#
# Akkadian signatures look slightly different, lacking the last two elements (after the /). The `parselemma()` function removes all the superfluous elements and breaks the string up into its parts. It returns a dictionary that lists all of these parts. The function `getline()` forwards this dictionary to the function `formatoutput()`, which uses its keys and values to build a usable data structure and/or to filter the data.

# %%
def parselemma(signature):
    output = {}
    signature = signature.replace(' ', '-')
    signature = signature.replace(',', ';') #remove spaces and commas from GuideWord and Sense
    oracc_words = re.sub("'\)$", "", signature) #remove ') from the end of the signature
    oracc_words = re.sub('^.*%', '', oracc_words) #remove everything before % in the signature

    
    sep_char = [":", "=", "$", "#", "[", "]", "//"] # these are the character sequences that separate
                                                    # the various elements of the signature
    for eachchar in sep_char:
        oracc_words = oracc_words.replace(eachchar, " ", 1) # ':' may appear in guideword/sense, so replace only once
    oracc_words_l = oracc_words.split() #split signature into a list
    output['lang'] = oracc_words_l[0]
    output['translit'] = oracc_words_l[1]
    output['citform'] = oracc_words_l[2]
    output['guide'] = oracc_words_l[3]
    output['sense'] = oracc_words_l[4]

    oracc_words_l[5] = oracc_words_l[5].replace("´", " ") # this separates pos from epos
    oracc_words_l[5] = oracc_words_l[5].split() #split into sub-list
    output['pos'] = oracc_words_l[5][0]
    output['epos'] = oracc_words_l[5][1]
    
    if output['lang'][0:2] == 'sux': # Sumerian or Emesal signature
        oracc_words_l[6] = oracc_words_l[6].replace("/", " ") # this separates norm from base in sux
        oracc_words_l[6] = oracc_words_l[6].split() #split into sub-list
        output['norm'] = oracc_words_l[6][0]
        output['base'] = oracc_words_l[6][1]
        output['morph'] = oracc_words_l[7]
    
    else:
        output['norm'] = oracc_words_l[6]
    
    return output

# %% [markdown]
# ## Compound Orthographic Forms
#
# Compound Orthographic Forms are combinations of two or more words that are written with a single graphemic complex. Examples are *im-ma-ti* for *ina mati* (when?) or {lu₂}EN.NAM for *bēl pīhati* (governor). In ORACC HTML, the words in a COF are combined in a single signature, separated by '&&':
#
# > javascript:pop1sig('saao/saa10','','@saao/saa10%akk-x-neoass:im-ma-ti=ina[in//in]PRP´PRP\$ina&&@saao/saa10%akk-x-neoass:=mati[when?//when?]QP´QP\$mati')
#
# The function `cof()` is called, when necessary, by `getline()`. It splits the signature at the '&&' separator and returns a list of signatures. The transliteration (in this case *im-ma-ti*), which is included only in the first signature, is isolated and assigned to the variable `translit`. This transliteration is inserted in the remaining signatures at the proper place.
#
# Occasionally, in some COF signatures, the second and further words do not have their own normalization (introduced by $) - this is, presumably, an irregularity in ORACC. If this is the case, normalization is supplied by assuming that it is equal to the citation form in the function `supplynorm()`.

# %%
def cof(signature):
    signature = signature.replace("javascript:pop1sig('", "")
    signature = signature.replace("')", "")
    translit = re.search(':(.*?)=', signature).group(1) #TODO replace the expression with positive look back
                                                        # and positive look ahead expression
    cofsignatures = signature.split('&&@')
    cofsignatures = [cofsignature.replace(':=', ':' + translit + '=') for cofsignature in cofsignatures]

    def supplynorm(cofsignature):
        if not '$' in cofsignature:
            citform = re.search('=(.*?)\[', cofsignature).group(1)
            cofsignature = cofsignature + '$' + citform
        return cofsignature
    
    cofsignatures = [supplynorm(cofsignature) for cofsignature in cofsignatures]
        
    return cofsignatures

# %% [markdown]
# # Process a Line
#
# The function `getline()` receives a line with metadata from the function `scrape()`. It returns a single variable (`line`) that contains the lines metadata and the formatted lemmata in a single string.
#
# The function needs two arguments. The first, `line_label`, includes all the metadata of the line: `id_text`, `text_name`, and `l_no` in a single string (separated by commas). The second argument, `line`, is a `BeautifulSoup` object that holds the HTML representation of a single line.
#
# Each line contains a series of words, represented as `signatures` in ORACC HTML. The function collects the signatures in the list `lemmas` and iterates over these. If a signature represents a Compound Orthographic Form (a combination of multiple lemmas, separated by '&&') it is sent to the function `cof()` in order to split the signature in its component forms.
#
# Each signature is sent to `parselemma()`, where it is analyzed. The function `parselemma()` returns a dictionary (`output`) that contains all the elements of the signature (transliteration, citation form, guide word, etc.). This dictionary is sent to the function `outputformat()` which returns a string, combining elements of the signature in the desired format (the default is language:citform[GuideWord]POS, as in sux:lugal[king]N). This string is added to the list `wordsinline`. Finally, once all lemmas (signatures) have been processed, the function builds a single string out of the `line_label` (metadata) and the formatted lemmas in `wordsinline`. This string is returned in the variable `line`.

# %%
def getline(line_label, line):
    wordsinline = [] #initialize list for the words in this line
    lemmas = line.findAll('a', {'class':'cbd'}, href=True)
    for eachlemma in lemmas:
        signature = eachlemma['href']
        if '&&@' in signature:  #Compound Orthographic Form, which results in multiple lemmas
            cofsignatures = cof(signature)
            for cofsignature in cofsignatures:
                output = parselemma(cofsignature)
                output_formatted = outputformat(output)
                if not output_formatted == None:
                    wordsinline.append(output_formatted)
        else:
            output = parselemma(signature)
            output_formatted = outputformat(output)
            if not output_formatted == None:
                wordsinline.append(output_formatted)
    line = line_label + ' '.join(wordsinline)
    return line

# %% [markdown]
# # Scrape a Single Text
#
# The function `scrape()` takes a single text file and uses the `BeautifulSoup` package to analyze the HTML and return the data in a csv (Comma Separated Values) format. The function is called by the main process.
#
# The function `scrape()` first identifies the name (or designation) of the text - if it cannot find the name, the text is not further processed and an error message is returned.
#
# The function then identifies a line and sends this line to the function `getline()` for further processing. The line number is a string that belongs to the attribute `class = 'xlabel'`. Text name, text id and line number are combined into a single string as `line_label` - which is sent to `getline()` as its first argument (the second is the line itself).
#
# If there is no `class = 'xlabel'` attribute, this means that the line belongs with the previous line as a single unit. This happens in interlinear bilinguals and, occasionally, in the representation of explanatory glosses (see, e.g. SAA 10, 044). In such cases the variable `line` from the previous iteration (which is a single string, concatenating `line_label` and the formatted lemmas) is sent, in its entirety, as the first argument to `getline()` so that the new lemma or lemmas will be added to the end of it.
#
# Finally all lines are assembled in the variable `csvformat`, which is returned to the main process.

# %%
def scrape(text_id):
    print('Parsing ' + text_id)
    line = ''
    csvformat ='id_text,text_name,l_no,text\n' #initialize output variable
    with open('HTML/' + text_id.replace('/', '_') + '.html', encoding='utf8') as f:
        raw_html = f.read()
    soup = BeautifulSoup(raw_html, "html.parser")
    name = soup.find('h1', {'class':'p3h2'}).string
    #if there is no text name, there are errors in atf and page was not built correctly
    if name == None:
        print(eachtextid + " is not built correctly.")
    else:
        #if name includes comma, replace comma with nothing
        name = name.replace(',','')
        print(eachtextid + ":" + name)
        lines = soup.findAll('tr', {'class':'l'})
        for index, eachline in enumerate(lines):
            if eachline.find('a', {'class':'cbd'}, href=True) == None: # if the line has no words
                continue                                               # go to next line
            if eachline.find('span', {'class': 'xlabel'}) != None:
                l_no = eachline.find('span', {'class': 'xlabel'}).string.replace(',', ';')
                line_label = text_id + ',' + name + ',' + l_no + ','
                line = getline(line_label, eachline)
                try:
                    nextline = lines[index + 1]
                    if nextline.find('span', {'class': 'xlabel'}) == None: #if next line has no line number
                        if nextline.find('a', {'class':'cbd'}, href=True) == None: #ignore if there are no lemmatized words
                            continue                                               # in next line
                        else:
                            line_label = line + ' '                         # otherwise join output with previous line
                            line = getline(line_label, nextline)
                except:
                    continue
            else:
                continue
            csvformat = csvformat + line + '\n'
    return csvformat

# %% [markdown]
# # Main Process
#
# The main process opens the list of text IDs (in the directory `Input`) to be processed and iterates over that list. The process calls the function `scrape()` which, in turn, calls the other functions defined above.
#
# The function creates a separate file for each of the scraped documents in the directory Output. A list of texts that could not be scraped is saved in the directory Error.

# %%
with open('Input/' + inputfile, mode = 'r', encoding='utf8') as f:
    textlist = f.read().splitlines()
for eachtextid in tqdm(textlist):
    sleep(0.01)
    eachtextid = eachtextid.rstrip()
    file = 'HTML/' + eachtextid.replace('/', '_') + '.html'
    try:
        csvformat = scrape(eachtextid)
        outputfile = 'Output/' + eachtextid.replace('/', '_') + '.txt'
        print("Saving " + outputfile + '\n')
    
        if not os.path.exists('Output'):
            os.mkdir('Output')
        
        with open(outputfile, mode = 'w', encoding='utf8') as writeFile:
            writeFile.write(csvformat)  

    except IOError:
        print(file + ' not available')
        textiderror = textiderror + eachtextid + '\n'

#Create error log
if not os.path.exists('Error'):
    os.mkdir('Error')
with open('Error/oraccerror.txt', mode='w', encoding='utf8') as writeFile:
    writeFile.write(textiderror)
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# Parsing dcclt/Q000039
# dcclt/Q000039:OB Nippur Ura 01
# sux:taškarin[boxwood]N
# sux:esi[tree]N
# sux:ŋešnu[tree]N
# sux:halub[tree]N
# sux:šagkal[tree]N
# sux:ŋešgana[tree]N
# sux:ŋešgana[tree]N
# sux:ŋešgana[tree]N
# sux:ŋeš[tree]N
# sux:ŋeštin[vine]N
# sux:ŋeštinkira[berry]N
# sux:ŋeštinkaʾa[grape]N
# sux:ŋeštinguruma[~vine]N
# sux:peš[fig]N
# sux:hašhur[apple]N
# sux:hašhur[apple]N
# sux:kur[mountain]N
# sux:šedug[tree]N
# sux:šenu[tree]N
# sux:še[cone]N
# sux:šinig[tamarisk]N
# sux:šinig[tamarisk]N
# sux:šinig[tamarisk]N
# sux:kur[mountain]N
# sux:šaršabid[tree]N
# sux:mes[tree]N
# sux:šaršabid[tree]N
# sux:lam[tree]N
# sux:eš[tree]N
# sux:usuh[tree]N
# sux:usuh[tree]N
# sux:usuh[tree]N
# sux:pa[branch]N
# sux:usuh[tree]N
# sux:a[water]N
# sux:še[cone]N
# sux:usuh[tree]N
# sux:pa[branch]N
# sux:usuh[tree]N
# sux:an[sky]N
# sux:usuh[tree]N
# sux:bir.GAM.la.e[tree]N
# sux:šimgig[tree]N
# sux:šennur[plum]N
# sux:šennur[plum]N
# sux:kur[mountain]N
# sux:lamgal[nut]N
# sux:lamtur[nut]N
# sux:allanum[oak]N
# sux:ildag[poplar]N
# sux:ildag[poplar]N
# sux:kur[mountain]N
# sux:ildag[poplar]N
# sux:ildag[poplar]N
# sux:šitan[water-channel]N
# sux:kur[wood]N
# sux:ŋešaʾabak[tree]N
# sux:ŋešaʾabak[tree]N
# sux:ŋipar[tree]N
# sux:manu[wood]N
# sux:manu[wood]N
# sux:šu[hand]N
# sux:manu[wood]N
# sux:gibil[firewood]N
# sux:manu[wood]N
# sux:nurma[pomegranate]N
# sux:KID.da[twig]N
# sux:KID.da[twig]N
# sux:KID.da[twig]N
# sux:mes[tree]N
# sux:mes[tree]N
# sux:mes[tree]N
# sux:mes[tree]N
# sux:mes.TU[tree]N
# sux:mes[tree]N
# sux:ki[place]N
# sux:mes[tree]N
# sux:halub[tree]N
# sux:harran[route]N
# sux:mes[tree]N
# sux:eren[cedar]N
# sux:mud[blood]N
# sux:eren[cedar]N
# sux:pa[branch]N
# sux:eren[cedar]N
# sux:asal[poplar]N
# sux:šurmen[cypress]N
# sux:zabalum[juniper]N
# sux:elammakum[tree]N
# sux:girim[flower]N
# sux:girim[flower]N
# sux:zirdum[olive]N
# sux:urnum[cedar]N
# sux:tiʾarum[tree]N
# sux:ilianum[tree]N
# sux:urzinum[tree]N
# sux:mirišŋara[tree]N
# sux:isimu[sprout]N
# sux:ŋeš[tree]N
# sux:gibil[sprout]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:suhuš[offshoot]N
# sux:ŋešnimbar[palm]N
# sux:kur[mountain]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:gun[load]N
# sux:ŋešnimbar[palm]N
# sux:lu₂.IM[criminal]N
# sux:ŋešnimbar[palm]N
# sux:lipiš[innards]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:izi[fire]N
# sux:ŋešnimbar[palm]N
# sux:eh[insect]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:šag[heart]N
# sux:ŋešnimbar[palm]N
# sux:suhur[tuft]N
# sux:ŋešnimbar[palm]N
# sux:ama[mother]N
# sux:ŋešnimbar[palm]N
# sux:kiri[orchard]N
# sux:ŋešnimbar[palm]N
# sux:kiri[orchard]N
# sux:ŋešnimbar[palm]N
# sux:aʾan[spadix]N
# sux:zag[side]N
# sux:ŋešnimbar[palm]N
# sux:pa[branch]N
# sux:ŋešnimbar[palm]N
# sux:pa[branch]N
# sux:ŋešnimbar[palm]N
# sux:dala[thorn]N
# sux:ŋešnimbar[palm]N
# sux:mud[stump]N
# sux:ŋešnimbar[palm]N
# sux:zena[midrib]N
# sux:ŋešnimbar[palm]N
# sux:su[fibers]N
# sux:ŋešnimbar[palm]N
# sux:su[fibers]N
# sux:ŋešnimbar[palm]N
# sux:su[fibers]N
# sux:ŋešnimbar[palm]N
# sux:tubala[harness]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:uluh[sapling]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:aʾan[spadix]N
# sux:ŋešnimbar[palm]N
# sux:kita[basket]N
# sux:ŋešnimbar[palm]N
# sux:kita[basket]N
# sux:zulum[date]N
# sux:ŋešnimbar[palm]N
# sux:niŋkiluh[broom]N
# sux:ŋešnimbar[palm]N
# sux:ŋešnimbar[palm]N
# sux:peš[frond]N
# sux:ŋešnimbar[palm]N
# sux:pešmur[~palm]N
# sux:ŋešnimbar[palm]N
# sux:pešbandazi[offshoot]N
# sux:ŋešnimbar[palm]N
# sux:asal[poplar]N
# sux:asal[poplar]N
# sux:kur[mountain]N
# sux:asal[poplar]N
# sux:asal[poplar]N
# sux:numun[seed]N
# sux:asal[poplar]N
# sux:ilur[tree]N
# sux:ad[bush]N
# sux:kišig[acacia]N
# sux:kišighar[tree]N
# sux:kišighar[tree]N
# sux:kur[mountain]N
# sux:samana[tree]N
# sux:samazum[tree]N
# sux:peškal[tree]N
# sux:ŠU.KAL[tree]N
# sux:šudiba[tree]N
# sux:ŠU.KAL[tree]N
# sux:šušum[licorice]N
# sux:šiqdum[almond]N
# sux:zarsi[plant]N
# sux:zirdum[olive]N
# sux:gizulumma[nettle?]N
# sux:buzunuma[plant]N
# sux:tulubum[tree]N
# sux:anta[tree]N
# sux:huš[plant]N
# sux:maš[plant]N
# sux:mašgurum[plant]N
# sux:guruʾuš[tree-trunk]N
# sux:arina[madder]N
# sux:arina[madder]N
# sux:gilim[foliage]N
# sux:an[sky]N
# sux:gilim[foliage]N
# sux:abzu[water]N
# sux:uluh[sapling]N
# sux:pa[branch]N
# sux:pa[branch]N
# sux:buniŋ[trough]N
# sux:aslum[rod]N
# sux:dibdib[waterclock]N
# sux:ŋešgana[pestle]N
# sux:ŋešdubdim[tool]N
# sux:sumungi[tool]N
# sux:tibala[sign]N
# sux:ŋeššudumak[tally]N
# sux:tun[container]N
# sux:ba[tool]N
# sux:ba[tool]N
# sux:zu[stone]N
# sux:ba[tool]N
# sux:amar[young]N
# sux:ba[tool]N
# sux:še[barley]N
# sux:ba[tool]N
# sux:ba[tool]N
# sux:gur[unit]N
# sux:ba[tool]N
# sux:pa[branch]N
# sux:ŋešnaruak[~stele]N
# sux:šibir[staff]N
# sux:niŋna[incense]N
# sux:guza[chair]N
# sux:guza[chair]N
# sux:guza[chair]N
# sux:guza[chair]N
# sux:sirda[cnne]N
# sux:guza[chair]N
# sux:munus[woman]N
# sux:guza[chair]N
# sux:malah[sailor]N
# sux:guza[chair]N
# sux:ŋeškiŋti[workshop]N
# sux:guza[chair]N
# sux:niŋba[gift]N
# sux:guza[chair]N
# sux:niŋšu[goods]N
# sux:guza[chair]N
# sux:gigir[chariot]N
# sux:guza[chair]N
# sux:anše[equid]N
# sux:guza[chair]N
# sux:kaskal[way]N
# sux:guza[chair]N
# sux:ŋarza[rites]N
# sux:guza[chair]N
# sux:namlugal[kingship]N
# sux:guza[chair]N
# sux:namen[priesthood]N
# sux:guza[chair]N
# sux:namnin[ladyship]N
# sux:guza[chair]N
# sux:šag[heart]N
# sux:guza[chair]N
# sux:šusar[string]N
# sux:guza[chair]N
# sux:guza[chair]N
# sux:šah[pig]N
# sux:guza[chair]N
# sux:guza[chair]N
# sux:guza[chair]N
# sux:malah[sailor]N
# sux:guza[chair]N
# sux:guza[chair]N
# sux:nita[male]N
# sux:guza[chair]N
# sux:munus[woman]N
# sux:guza[chair]N
# sux:unkin[assembly]N
# sux:guza[chair]N
# sux:lukur[priestess]N
# sux:guza[chair]N
# sux:gidim[ghost]N
# sux:guza[chair]N
# sux:ki[place]N
# sux:guza[chair]N
# sux:guza[chair]N
# sux:taškarin[boxwood]N
# sux:guza[chair]N
# sux:esi[tree]N
# sux:guza[chair]N
# sux:šagkal[tree]N
# sux:guza[chair]N
# sux:mes[tree]N
# sux:guza[chair]N
# sux:mes[tree]N
# sux:guza[chair]N
# sux:mes[tree]N
# sux:guza[chair]N
# sux:gar[knob]N
# sux:guza[chair]N
# sux:gar[knob]N
# sux:kugbabbar[silver]N
# sux:guza[chair]N
# sux:gar[knob]N
# sux:kugsig[gold]N
# sux:guza[chair]N
# sux:gar[knob]N
# sux:zabar[bronze]N
# sux:guza[chair]N
# sux:gar[knob]N
# sux:kuš[skin]N
# sux:bad[leg]N
# sux:guza[chair]N
# sux:saŋ[head]N
# sux:guza[chair]N
# sux:ŋešdi[rung]N
# sux:guza[chair]N
# sux:izzi[wall]N
# sux:guza[chair]N
# sux:umbin[base]N
# sux:guza[chair]N
# sux:šuʾa[stool]N
# sux:šuʾa[stool]N
# sux:dus[bathroom]N
# sux:šuʾa[stool]N
# sux:nagar[carpenter]N
# sux:šuʾa[stool]N
# sux:burgul[stone-cutter]N
# sux:šuʾa[stool]N
# sux:tibira[sculptor]N
# sux:šuʾa[stool]N
# sux:kaskal[way]N
# sux:šuʾa[stool]N
# sux:niŋgula[greatness]N
# sux:ŋirigub[footstool]N
# sux:ŋirigub[footstool]N
# sux:ŋirigub[footstool]N
# sux:zu[tooth]N
# sux:amsi[elephant]N
# sux:ŋešnud[bed]N
# sux:ŋeš.nud.AŠ.nud[bed]N
# sux:ŋešnud[bed]N
# sux:kinud[bedroom]N
# sux:ŋešnud[bed]N
# sux:gu[neck]N
# sux:ŋešnud[bed]N
# sux:umbin[nail]N
# sux:ŋešnud[bed]N
# sux:umbin[nail]N
# sux:gud[ox]N
# sux:ŋešnud[bed]N
# sux:šatuku[mattress]N
# sux:ŋešnud[bed]N
# sux:šatuku[mattress]N
# sux:siki[hair]N
# sux:garig[comb]N
# sux:ŋešnud[bed]N
# sux:zag[side]N
# sux:andul[shade]N
# sux:ŋešnud[bed]N
# sux:barsig[garment]N
# sux:ŋešnud[bed]N
# sux:bad[leg]N
# sux:ŋešnud[bed]N
# sux:saŋ[head]N
# sux:ŋešnud[bed]N
# sux:ŋešdi[rung]N
# sux:ŋešnud[bed]N
# sux:izzi[wall]N
# sux:ŋešnud[bed]N
# sux:umbin[base]N
# sux:ŋešnud[bed]N
# sux:dilimgal[dish]N
# sux:dilim[spoon]N
# sux:dilimbanda[bowl]N
# sux:maltum[bowl]N
# sux:banšur[table]N
# sux:dilim[spoon]N
# sux:banšur[table]N
# sux:umbin[base]N
# sux:banšur[table]N
# sux:banšurzaggula[table]N
# sux:banšur[table]N
# sux:zagŋara[shrine]N
# sux:kaŋeškarak[table]N
# sux:kaŋeškarak[table]N
# sux:zu[tooth]N
# sux:amsi[elephant]N
# sux:maštakda[wooden-object]N
# sux:emerah[jug]N
# sux:emerah[jug]N
# sux:ga[milk]N
# sux:emerah[jug]N
# sux:murzanum[wooden-object]N
# sux:kuŋ[stair]N
# sux:kuŋ[stair]N
# sux:bad[wall]N
# sux:kuŋ[stair]N
# sux:galam[staircase]N
# sux:u[planking]N
# sux:kuŋ[stair]N
# sux:suku[pole]N
# sux:kuŋ[stair]N
# sux:buniŋ[trough]N
# sux:buniŋ[trough]N
# sux:buniŋ[trough]N
# sux:naŋa[mortar]N
# sux:naŋa[mortar]N
# sux:še[barley]N
# sux:naŋa[mortar]N
# sux:ŋeši[sesame]N
# sux:naŋa[mortar]N
# sux:esir[bitumen]N
# sux:ea[~bitumen]N
# sux:tukul[weapon]N
# sux:naŋasikaz[pestle]N
# sux:ŋešgana[pestle]N
# sux:girah[tool]N
# sux:mete[appropriate-thing]N
# sux:šidim[builder]N
# sux:emesig[plank]N
# sux:miriza[plank]N
# sux:miriza[plank]N
# sux:zag[side]N
# sux:ma[ship]N
# sux:magur[barge]N
# sux:ma[ship]N
# sux:ma[ship]N
# sux:maʾu[barge]N
# sux:madala[bundle]N
# sux:ma[ship]N
# sux:šukud[fisherman]N
# sux:ma[ship]N
# sux:ma[ship]N
# sux:šu[hand]N
# sux:ma[ship]N
# sux:ma[ship]N
# sux:ma[ship]N
# sux:ma[ship]N
# sux:dim[post]N
# sux:ma[ship]N
# sux:ma[ship]N
# sux:ma[ship]N
# sux:gur[unit]N
# sux:ma[ship]N
# sux:gur[unit]N
# sux:ma[ship]N
# sux:gur[unit]N
# sux:ma[ship]N
# sux:gur[unit]N
# sux:ma[ship]N
# sux:gur[unit]N
# sux:ma[ship]N
# sux:gur[unit]N
# sux:ma[ship]N
# sux:gur[unit]N
# sux:ma[ship]N
# sux:gur[unit]N
# sux:ma[ship]N
# sux:magur[barge]N
# sux:magur[barge]N
# sux:ma[ship]N
# sux:nurum[light]N
# sux:ma[ship]N
# sux:u[planking]N
# sux:ma[ship]N
# sux:ema[cabin]N
# sux:si[horn]N
# sux:ma[ship]N
# sux:anše[equid]N
# sux:ma[ship]N
# sux:dim[post]N
# sux:ma[ship]N
# sux:dib[board]N
# sux:ma[ship]N
# sux:saŋ[head]N
# sux:ma[ship]N
# sux:zipah[unit]N
# sux:ma[ship]N
# sux:egir[back]N
# sux:ma[ship]N
# sux:ma[ship]N
# sux:maʾaddir[ferryboat]N
# sux:ma[ship]N
# sux:lugal[king]N
# sux:madu[~boat]N
# sux:zag[side]N
# sux:madu[~boat]N
# sux:madu[~boat]N
# sux:madu[~boat]N
# sux:madu[~boat]N
# sux:targul[pole]N
# sux:targul[pole]N
# sux:zigan[rudder]N
# sux:dilim[spoon]N
# sux:zigan[rudder]N
# sux:zigan[rudder]N
# sux:antibal[sign]N
# sux:zinhur[~ship]N
# sux:gag[nail]N
# sux:ir[peg]N
# sux:eškiri[rope]N
# sux:gag[nail]N
# sux:eškiri[rope]N
# sux:šibir[staff]N
# sux:gag[nail]N
# sux:šibir[staff]N
# sux:gabar[herder]N
# sux:gigir[chariot]N
# sux:e[house]N
# sux:gigir[chariot]N
# sux:e[house]N
# sux:usan[whip]N
# sux:gigir[chariot]N
# sux:gigir[chariot]N
# sux:kun[tail]N
# sux:gigir[chariot]N
# sux:GUL[~chariot]N
# sux:gigir[chariot]N
# sux:kindu[earth]N
# sux:gigir[chariot]N
# sux:sahargi[dust-guard]N
# sux:gigir[chariot]N
# sux:sudin[~chariot]N
# sux:gigir[chariot]N
# sux:sulummar[rope]N
# sux:gigir[chariot]N
# sux:saŋkul[bolt]N
# sux:gigir[chariot]N
# sux:saŋdur[seat]N
# sux:gigir[chariot]N
# sux:ŋirigub[footstool]N
# sux:gigir[chariot]N
# sux:mud[tube]N
# sux:gigir[chariot]N
# sux:gag[nail]N
# sux:mud[tube]N
# sux:gigir[chariot]N
# sux:šudul[yoke]N
# sux:gigir[chariot]N
# sux:gag[nail]N
# sux:šudul[yoke]N
# sux:gigir[chariot]N
# sux:umbin[wheel]N
# sux:gigir[chariot]N
# sux:gag[nail]N
# sux:umbin[wheel]N
# sux:gigir[chariot]N
# sux:si[horn]N
# sux:gigir[chariot]N
# sux:gaba[chest]N
# sux:gigir[chariot]N
# sux:gabaŋal[guard]N
# sux:gigir[chariot]N
# sux:usan[whip]N
# sux:usan[whip]N
# sux:eme[tongue]N
# sux:usan[whip]N
# sux:usan[whip]N
# sux:gagsila[harness]N
# sux:zara[pivot]N
# sux:gagsila[harness]N
# sux:umbin[wheel]N
# sux:gagsila[harness]N
# sux:gagsila[harness]N
# sux:DUB.du₃[~vehicle]N
# sux:DUB.du₃[~vehicle]N
# sux:DUB.du₃[~vehicle]N
# sux:šag[heart]N
# sux:margida[cart]N
# sux:margida[cart]N
# sux:guza[chair]N
# sux:margida[cart]N
# sux:zara[pivot]N
# sux:margida[cart]N
# sux:gag[nail]N
# sux:zara[pivot]N
# sux:margida[cart]N
# sux:saŋkul[bolt]N
# sux:margida[cart]N
# sux:saŋdur[seat]N
# sux:margida[cart]N
# sux:ŋirigub[footstool]N
# sux:margida[cart]N
# sux:mud[stump]N
# sux:margida[cart]N
# sux:gag[nail]N
# sux:mud[tube]N
# sux:margida[cart]N
# sux:šudul[yoke]N
# sux:margida[cart]N
# sux:gag[nail]N
# sux:šudul[yoke]N
# sux:margida[cart]N
# sux:umbin[wheel]N
# sux:margida[cart]N
# sux:gag[nail]N
# sux:umbin[wheel]N
# sux:margida[cart]N
# sux:usakar[moon]N
# sux:margida[cart]N
# sux:gag[nail]N
# sux:usakar[moon]N
# sux:margida[cart]N
# sux:manhara[vessel]N
# sux:margida[cart]N
# sux:endur[navel?]N
# sux:margida[cart]N
# sux:ig[door]N
# sux:ig[door]N
# sux:ig[door]N
# sux:i[oil]N
# sux:ig[door]N
# sux:i[oil]N
# sux:ig[door]N
# sux:leʾum[board]N
# sux:ig[door]N
# sux:dib[board]N
# sux:ig[door]N
# sux:sah[mat]N
# sux:ig[door]N
# sux:papah[cella]N
# sux:ig[door]N
# sux:ig[door]N
# sux:maštab[twin]N
# sux:ig[door]N
# sux:uma[triumph]N
# sux:ig[door]N
# sux:ul[fruit]N
# sux:ig[door]N
# sux:zena[midrib]N
# sux:ig[door]N
# sux:miriza[plank]N
# sux:ig[door]N
# sux:kan[gate]N
# sux:tilla[street]N
# sux:ig[door]N
# sux:kan[gate]N
# sux:egal[palace]N
# sux:suku[pole]N
# sux:ig[door]N
# sux:u[planking]N
# sux:ig[door]N
# sux:usakar[moon]N
# sux:ig[door]N
# sux:barda[crossbar]N
# sux:ig[door]N
# sux:dula[depth]N
# sux:ig[door]N
# sux:ir[peg]N
# sux:ig[door]N
# sux:suhub[bolt]N
# sux:ig[door]N
# sux:suhub[bolt]N
# sux:šugi[bolt]N
# sux:nukušu[~door]N
# sux:nukušu[~door]N
# sux:nukušu[~door]N
# sux:saŋkul[bolt]N
# sux:saŋkul[bolt]N
# sux:eš[rope]N
# sux:saŋkul[bolt]N
# sux:saŋkul[bolt]N
# sux:siŋar[bolt]N
# sux:gag[nail]N
# sux:siŋar[bolt]N
# sux:siŋar[bolt]N
# sux:guʾe[textile]N
# sux:mud[tube]N
# sux:gag[nail]N
# sux:mud[tube]N
# sux:šerim[~loom]N
# sux:šerim[~loom]N
# sux:kura[~loom]N
# sux:nura[~loom]N
# sux:ilila[lever]N
# sux:barbar[shuttle]N
# sux:tugtug[~loom]N
# sux:niŋzu[~loom]N
# sux:ŋešgina[~loom]N
# sux:niŋmenbulug[~loom]N
# sux:ašita[equipment]N
# sux:tug[textile]N
# sux:garig[comb]N
# sux:garig[comb]N
# sux:siki[hair]N
# sux:garig[comb]N
# sux:saŋdu[head]N
# sux:garig[comb]N
# sux:pa[branch]N
# sux:mušen[bird]N
# sux:garig[comb]N
# sux:eban[pair]N
# sux:balak[spindle]N
# sux:e[house]N
# sux:balak[spindle]N
# sux:saŋ[head]N
# sux:balak[spindle]N
# sux:balak[spindle]N
# sux:mete[appropriate-thing]N
# sux:balak[spindle]N
# sux:ellag[ball]N
# sux:ŋešellag[tool]N
# sux:ellag[ball]N
# sux:madal[pole]N
# sux:madal[pole]N
# sux:malalum[container]N
# sux:gazinbu[pole]N
# sux:sahargid[roller]N
# sux:ŋešpu[rim]N
# sux:ŋešpu[rim]N
# sux:mansim[sieve]N
# sux:kim[willow]N
# sux:mes[blackness]N
# sux:ŋešrin[scales]N
# sux:ŋešrin[scales]N
# sux:ŋešrin[scales]N
# sux:gun[load]N
# sux:ŋešrin[scales]N
# sux:mana[unit]N
# sux:e[house]N
# sux:ŋešrin[scales]N
# sux:dilim[spoon]N
# sux:ŋešrin[scales]N
# sux:apin[plow]N
# sux:apin[plow]N
# sux:šu[hand]N
# sux:apin[plow]N
# sux:apin[plow]N
# sux:apin[plow]N
# sux:tugsaga[plow]N
# sux:apin[plow]N
# sux:saŋ[head]N
# sux:apin[plow]N
# sux:gud[ox]N
# sux:saŋ[head]N
# sux:apin[plow]N
# sux:eme[tongue]N
# sux:apin[plow]N
# sux:kašu[~plow]N
# sux:apin[plow]N
# sux:šusaŋ[compressor]N
# sux:apin[plow]N
# sux:igiŋal[~plow]N
# sux:apin[plow]N
# sux:niŋkud[~plowshare]N
# sux:apin[plow]N
# sux:niŋŋeštug[~plow]N
# sux:apin[plow]N
# sux:sala[~plow]N
# sux:apin[plow]N
# sux:gag[nail]N
# sux:sala[~plow]N
# sux:apin[plow]N
# sux:nig[~plow]N
# sux:apin[plow]N
# sux:gag[nail]N
# sux:nig[~plow]N
# sux:apin[plow]N
# sux:šudul[yoke]N
# sux:apin[plow]N
# sux:gag[nail]N
# sux:šudul[yoke]N
# sux:apin[plow]N
# sux:apin[plow]N
# sux:gag[nail]N
# sux:apin[plow]N
# sux:da[side-board]N
# sux:apin[plow]N
# sux:a[arm]N
# sux:apin[plow]N
# sux:apin[plow]N
# sux:leʾum[board]N
# sux:apin[plow]N
# sux:ninda[seed-funnel]N
# sux:apin[plow]N
# sux:a[arm]N
# sux:gud[ox]N
# sux:apin[plow]N
# sux:anzam[vessel]N
# sux:apin[plow]N
# sux:gag[nail]N
# sux:sa[sinew]N
# sux:ŋušur[harrow]N
# sux:ŋušur[harrow]N
# sux:sar[garden]N
# sux:ŋušur[harrow]N
# sux:zu[tooth]N
# sux:sa[sinew]N
# sux:ŋušur[harrow]N
# sux:ŋušur[harrow]N
# sux:saŋ[head]N
# sux:ŋušur[harrow]N
# sux:damga[~plow]N
# sux:suhur[tool]N
# sux:suhur[tool]N
# sux:gud[ox]N
# sux:al[hoe]N
# sux:al[hoe]N
# sux:zu[tooth]N
# sux:alšub[tool]N
# sux:al[hoe]N
# sux:zu[tooth]N
# sux:al[hoe]N
# sux:zu[tooth]N
# sux:al[hoe]N
# sux:zu[tooth]N
# sux:ušub[brick-mold]N
# sux:ušub[brick-mold]N
# sux:ab[window]N
# sux:ušub[brick-mold]N
# sux:šeg[brick]N
# sux:ušub[brick-mold]N
# sux:šeg[brick]N
